# %% [markdown]
# ### Madyama Purusha (Second Person)

# %%
def sinhala_to_english(text):
    # Define a mapping dictionary for Sinhalese to English letters
    sinhala_to_english_mapping = {
        'ම': 'm', 'අ': 'a', 'ද': 'd', 'ග': 'g', 'ෙ': 'e',
        'හ': 'h', 'ප': 'p', 'බ': 'b',
        'ඉ': 'i', 'න': 'n', 'ට': 't', 'ත': 'tha',
        'ච': 'c', 'එ': 'e', 'ය': 'y', 'ල': 'l', 'ව': 'w',
        'ැ': 'ae', 'ළ': 'l', 'ආ': 'aa', 'ං': 'n',
        'ර': 'r', 'ජ': 'j', 'ස': 's', 'ෆ': 'f', 'භ': 'b',
        'ය': 'y', 'ි': 'i', 'ක': 'k',
        'ො': 'o', 'ඩ': 'd', '්': '', ' ': ' ', '.': '.',
        'ා': 'a', 'ැ': 'ae', 'ෑ': 'aee', 'ි': 'i', 'ී': 'ii',
        'ු': 'u', 'ූ': 'uu', 'ෘ': 'u', 'ෙ': 'e', 'ේ': 'ee',
        'ෛ': 'ei', 'ෝ': 'oo', 'ෞ': 'ou',
        'ෟ': 'o', 'ෲ': 'lu', 'ෳ': 'lu'
    }

    # Perform the conversion
    english_text = ""
    for char in text:
        if char in sinhala_to_english_mapping:
            english_text += sinhala_to_english_mapping[char]
        else:
            english_text += char

    return english_text

# %%
import re
def check_grammar(text, letter_combination):
    # Split the text into sentences
    sentences = text.split('.')

    results = []

    for sentence in sentences:
        # Split each sentence into words
        words = sentence.split()

        # Check if there are at least two words in the sentence
        if len(words) >= 1:
            last_word = words[-1].strip(".,!?")

            # Check if the last two letters of the last word match the specified letter combination
            if last_word[-2:].lower() == letter_combination.lower():
                results.append("Correct Grammar")
            else:
                results.append("Incorrect Grammar")
        else:
            # If there are no words in the sentence, it's considered incorrect grammar
            results.append("Incorrect Grammar")

    return results

# %%
import csv

# Provide a valid file path for your CSV file
# Specify the encoding that matches your CSV file

file_encoding = 'utf-8'  # You can change this to 'latin-1' or other encodings if needed
csv_file_path = "SecondPerson-PresentTense.csv"  # Replace with the path to your CSV file

all_rows = []  # List to store all rows as strings

with open(csv_file_path, 'r', newline='', encoding=file_encoding) as csvfile:
    csv_reader = csv.reader(csvfile)

    for row in csv_reader:
        if row:  # Check if the row is not empty
            # Combine the row's elements into a single string separated by dots
            row_string = '.'.join(row)
            all_rows.append(row_string)

# %%
joined_rows = '.'.join(all_rows)

# %%
all_rows
# Out:
# ['\ufeffතී දිය නෑමට ගඟට යහි',
#  'තෝ  දිය නෑමට ගඟට යහි',
#  'නුඹ දිය නෑමට ගඟට යහි',
#  'ඔබ දිය නෑමට ගඟට යහි',
#  'තෙපි දිය නෑමට ගඟට යහු',
#  'තොපි දිය නෑමට ගඟට යහු',
#  'නුඹලා දිය නෑමට ගඟට යහු',
#  'ඔබ දිය නෑමට ගඟට යහු',
#  'තී සිංහල ගීතයක් ගයහි',
#  'තෝ සිංහල ගීතයක් ගයහි',
#  'නුඹ සිංහල ගීතයක් ගයහි',
#  'ඔබ සිංහල ගීතයක් ගයහි',
#  'තෙපි සිංහල ගීතයක් ගයහු',
#  'තොපි සිංහල ගීතයක් ගයහු',
#  'නුඹලා සිංහල ගීතයක් ගයහු',
#  'ඔබ සිංහල ගීතයක් ගයහු',
#  'තී කවියක් ගයහි',
#  'තෝ කවියක් ගයහි',
#  'නුඹ කවියක් ගයහි',
#  'ඔබ කවියක් ගයහි',
#  'තෙපි කවියක් ගයහු',
#  'තොපි කවියක් ගයහු',
#  'නුඹලා කවියක් ගයහු',
#  'ඔබ කවියක් ගයහු',
#  'තී ක්\u200dරීඩා පිටියේ ක්\u200dරීඩා කරහි',
#  'තෝ ක්\u200dරීඩා පිටියේ ක්\u200dරීඩා කරහි',
#  'නුඹ ක්\u200dරීඩා පිටියේ ක්\u200dරීඩා කරහි',
#  'ඔබ ක්\u200dරීඩා පිටියේ ක්\u200dරීඩා කරහි',
#  'තෙපි ක්\u200dරීඩා පිටියේ ක්\u200dරීඩා කරහු',
#  'තොපි ක්\u200dරීඩා පිටියේ ක්\u200dරීඩා කරහු',
#  'නුඹලා ක්\u200dරීඩා පිටියේ ක්\u200dරීඩා කරහු',
#  'ඔබ ක්\u200dරීඩා පිටියේ ක්\u200dරීඩා කරහු',
#  'තී ආදරයෙන් දෙමව්පියන්ට සලකහි',
#  'තෝ ආදරයෙන් දෙමව්පියන්ට සලකහි',
#  'නුඹ ආදරයෙන් දෙමව්පියන්ට සලකහි',
#  'ඔබ ආදරයෙන් දෙමව්පියන්ට සලකහි',
#  'තෙපි ආදරයෙන් දෙමව්පියන්ට සලකහු',
#  'තොපි ආදරයෙන් දෙමව්පියන්ට සලකහු',
#  'නුඹලා ආදරයෙන් දෙමව්පියන්ට සලකහු',
#  'ඔබ ආදරයෙන් දෙමව්පියන්ට සලකහු',
#  'තී පොත් පාඩම් කරහි',
#  'තෝ පොත් පාඩම් කරහි',
#  'නුඹ පොත් පාඩම් කරහි',
#  'ඔබ පොත් පාඩම් කරහි',
#  'තෙපි පොත් පාඩම් කරහු',
#  'තොපි පොත් පාඩම් කරහු',
#  'නුඹලා පොත් පාඩම් කරහු',
#  'ඔබ පොත් පාඩම් කරහු',
#  'තී දිනපතා පාසලට යහි',
#  'තෝ දිනපතා පාසලට යහි',
#  'නුඹ දිනපතා පාසලට යහි',
#  'ඔබ දිනපතා පාසලට යහි',
#  'තෙපි දිනපතා පාසලට යහු',
#  'තොපි දිනපතා පාසලට යහු',
#  'නුඹලා දිනපතා පාසලට යහු',
#  'ඔබ දිනපතා පාසලට යහු',
#  'තී වේගයෙන් ඔන්චිලි පදිහි',
#  'තෝ වේගයෙන්ඔන්චිලි පදිහි',
#  'නුඹ වේගයෙන් ඔන්චිලි පදිහි',
#  'ඔබ වේගයෙන් ඔන්චිලි පදිහි',
#  'තෙපි වේගයෙන් ඔන්චිලි පදිහු',
#  'තොපි වේගයෙන් ඔන්චිලි පදිහු',
#  'නුඹලා වේගයෙන්ඔන්චිලි පදිහු',
#  'ඔබ වේගයෙන් ඔන්චිලි පදිහු',
#  'තී නුවර පෙරහැර බැලීමට යහි',
#  'තෝ නුවර පෙරහැර බැලීමට යහි',
#  'නුඹ නුවර පෙරහැර බැලීමට යහි',
#  'ඔබ නුවර පෙරහැර බැලීමට යහි',
#  'තෙපි නුවර පෙරහැර බැලීමට යහු',
#  'තොපි නුවර පෙරහැර බැලීමට යහු',
#  'නුඹලා නුවර පෙරහැර බැලීමට යහු',
#  'ඔබ නුවර පෙරහැර බැලීමට යහු',
#  'තී දිනපතා පන්සලට යහි',
#  'තෝ දිනපතා පන්සලට යහි',
#  'නුඹ දිනපතා පන්සලට යහි',
#  'ඔබ දිනපතා පන්සලට යහි',
#  'තෙපි දිනපතා පන්සලට යහු',
#  'තොපි දිනපතා පන්සලට යහු',
#  'නුඹලා දිනපතා පන්සලට යහු',
#  'ඔබ දිනපතා පන්සලට යහු',
#  'තී ඉතා මිහිරි ලෙස ගීතයක් ගයහි',
#  'තෝ ඉතා මිහිරි ලෙස ගීතයක් ගයහි',
#  'නුඹ ඉතා මිහිරි ලෙස ගීතයක් ගයහි',
#  'ඔබ ඉතා මිහිරි ලෙස ගීතයක් ගයහි',
#  'තෙපි ඉතා මිහිරි ලෙස ගීතයක් ගයහු',
#  'තොපි ඉතා මිහිරි ලෙස ගීතයක් ගයහු',
#  'නුඹලා ඉතා මිහිරි ලෙස ගීතයක් ගයහු',
#  'ඔබ ඉතා මිහිරි ලෙස ගීතයක් ගයහු',
#  'තී ලස්සන ගීතයකට නටහි',
#  'තෝ ලස්සන ගීතයකට නටහි',
#  'නුඹ ලස්සන ගීතයකට නටහි',
#  'ඔබ ලස්සන ගීතයකට නටහි',
#  'තෙපි ලස්සන ගීතයකට නටහු',
#  'තොපි ලස්සන ගීතයකට නටහු',
#  'නුඹලා ලස්සන ගීතයකට නටහු',
#  'ඔබ ලස්සන ගීතයකට නටහු',
#  'තී දිනපතා රැකියාවට යහි',
#  'තෝ දිනපතා රැකියාවට යහි',
#  'නුඹ දිනපතා රැකියාවට යහි',
#  'ඔබ දිනපතා රැකියාවට යහි',
#  'තෙපි දිනපතා රැකියාවට යහු',
#  'තොපි දිනපතා රැකියාවට යහු',
#  'නුඹලා දිනපතා රැකියාවට යහු',
#  'ඔබ දිනපතා රැකියාවට යහු',
#  'යුෂ්මතා බොරු කියහි',
#  'යුෂ්මතිය බොරු කියහි',
#  'යුෂ්මත්හු බොරු කියහු',
#  'යුෂ්මතා කාර්යය අවසන් කරහි',
#  'යුෂ්මතිය කාර්යය අවසන් කරහි',
#  'යුෂ්මත්හු කාර්යය අවසන් කරහු']

# %%
joined_rows
# Out:
# '\ufeffතී දිය නෑමට ගඟට යහි.තෝ  දිය නෑමට ගඟට යහි.නුඹ දිය නෑමට ගඟට යහි.ඔබ දිය නෑමට ගඟට යහි.තෙපි දිය නෑමට ගඟට යහු.තොපි දිය නෑමට ගඟට යහු.නුඹලා දිය නෑමට ගඟට යහු.ඔබ දිය නෑමට ගඟට යහු.තී සිංහල ගීතයක් ගයහි.තෝ සිංහල ගීතයක් ගයහි.නුඹ සිංහල ගීතයක් ගයහි.ඔබ සිංහල ගීතයක් ගයහි.තෙපි සිංහල ගීතයක් ගයහු.තොපි සිංහල ගීතයක් ගයහු.නුඹලා සිංහල ගීතයක් ගයහු.ඔබ සිංහල ගීතයක් ගයහු.තී කවියක් ගයහි.තෝ කවියක් ගයහි.නුඹ කවියක් ගයහි.ඔබ කවියක් ගයහි.තෙපි කවියක් ගයහු.තොපි කවියක් ගයහු.නුඹලා කවියක් ගයහු.ඔබ කවියක් ගයහු.තී ක්\u200dරීඩා පිටියේ ක්\u200dරීඩා කරහි.තෝ ක්\u200dරීඩා පිටියේ ක්\u200dරීඩා කරහි.නුඹ ක්\u200dරීඩා පිටියේ ක්\u200dරීඩා කරහි.ඔබ ක්\u200dරීඩා පිටියේ ක්\u200dරීඩා කරහි.තෙපි ක්\u200dරීඩා පිටියේ ක්\u200dරීඩා කරහු.තොපි ක්\u200dරීඩා පිටියේ ක්\u200dරීඩා කරහු.නුඹලා ක්\u200dරීඩා පිටියේ ක්\u200dරීඩා කරහ
# %% [markdown]
# ### For the "THO,Nuba" Sentence

# %%
input_text = joined_rows
letter_comb = "හි"

# %%
# Convert Sinhala letters to English
english_text = sinhala_to_english(input_text)
print("Input Text in Sinhala:")
print(input_text)
print("\nConverted to English Letters:")
print(english_text)

start_text = sinhala_to_english(letter_comb)
print("\nConverted Starting Letter:")
print(start_text)


def count_correct_grammar_sentences(english_text, start_text):
    # Check grammar using the previous code
    results = check_grammar(english_text, start_text)

    correct_grammar_count = results.count("Correct Grammar")
    incorrect_grammar_count = results.count("Incorrect Grammar")

    return correct_grammar_count, incorrect_grammar_count


# Check grammar using the previous code
results = check_grammar(english_text, start_text)
print("\nGrammar Check Results:")
sentences = english_text.split('.')
for i, sentence in enumerate(sentences):
    print(f"Sentence {i + 1}: {sentence.strip()}")
    print(f"Grammar: {results[i]}\n")

# Example usage:
correct_grammar_count, incorrect_grammar_count = count_correct_grammar_sentences(english_text, start_text)

print(f"Number of Correct Grammar Sentences: {correct_grammar_count}")
print(f"Number of Incorrect Grammar Sentences: {incorrect_grammar_count - 1}")
# Out:
# Input Text in Sinhala:
# ﻿තී දිය නෑමට ගඟට යහි.තෝ  දිය නෑමට ගඟට යහි.නුඹ දිය නෑමට ගඟට යහි.ඔබ දිය නෑමට ගඟට යහි.තෙපි දිය නෑමට ගඟට යහු.තොපි දිය නෑමට ගඟට යහු.නුඹලා දිය නෑමට ගඟට යහු.ඔබ දිය නෑමට ගඟට යහු.තී සිංහල ගීතයක් ගයහි.තෝ සිංහල ගීතයක් ගයහි.නුඹ සිංහල ගීතයක් ගයහි.ඔබ සිංහල ගීතයක් ගයහි.තෙපි සිංහල ගීතයක් ගයහු.තොපි සිංහල ගීතයක් ගයහු.නුඹලා සිංහල ගීතයක් ගයහු.ඔබ සිංහල ගීතයක් ගයහු.තී කවියක් ගයහි.තෝ කවියක් ගයහි.නුඹ කවියක් ගයහි.ඔබ කවියක් ගයහි.තෙපි කවියක් ගයහු.තොපි කවියක් ගයහු.නුඹලා කවියක් ගයහු.ඔබ කවියක් ගයහු.තී ක්‍රීඩා පිටියේ ක්‍රීඩා කරහි.තෝ ක්‍රීඩා පිටියේ ක්‍රීඩා කරහි.නුඹ ක්‍රීඩා පිටියේ ක්‍රීඩා කරහි.ඔබ ක්‍රීඩා පිටියේ ක්‍රීඩා කරහි.තෙපි ක්‍රීඩා පිටියේ ක්‍රීඩා කරහු.තොපි ක්‍රීඩා පිටියේ ක්‍රීඩා කරහු.නුඹලා ක්‍රීඩා පිටියේ ක්‍රීඩා කරහු.ඔබ ක්‍රීඩා පිටියේ ක්‍රීඩා කරහු.තී ආදරයෙන් දෙමව්පියන්ට සලකහි.තෝ ආදරයෙන් දෙමව්පියන්ට සලකහි.නුඹ ආදරයෙන් දෙමව්පියන්ට සලකහි.ඔබ ආදරයෙන් දෙමව්පියන්ට සලකහි.තෙපි ආදරයෙන් දෙමව්පියන්ට සලකහු.තොපි ආදරයෙන් දෙමව්පියන්ට සලකහු.නුඹලා ආදරයෙන් දෙමව්පියන්ට සලකහු.ඔබ ආදරයෙන් දෙමව්පියන්ට සලක
ri les giithayk gyhu.nuඹla ithaa mihiri les giithayk gyhu.ඔb ithaa mihiri les giithayk gyhu.thaii lssn giithaykt nthi.thaoo lssn giithaykt nthi.nuඹ lssn giithaykt nthi.ඔb lssn giithaykt nthi.thaepi lssn giithaykt nthu.thaopi lssn giithaykt nthu.nuඹla lssn giithaykt nthu.ඔb lssn giithaykt nthu.thaii dinpthaa raekiyawt yhi.thaoo dinpthaa raekiyawt yhi.nuඹ dinpthaa raekiyawt yhi.ඔb dinpthaa raekiyawt yhi.thaepi dinpthaa raekiyawt yhu.thaopi dinpthaa raekiyawt yhu.nuඹla dinpthaa raekiyawt yhu.ඔb dinpthaa raekiyawt yhu.yuෂmthaa boru kiyhi.yuෂmthaiy boru kiyhi.yuෂmthahu boru kiyhu.yuෂmthaa karyy awsn krhi.yuෂmthaiy karyy awsn krhi.yuෂmthahu karyy awsn krhu
#
# Converted Starting Letter:
# hi
#
# Grammar Check Results:
# Sentence 1: ﻿thaii diy naeemt gඟt yhi
# Grammar: Correct Grammar
#
# Sentence 2: thaoo  diy naeemt gඟt yhi
# Grammar: Correct Grammar
#
# Sentence 3: nuඹ diy naeemt gඟt yhi
# Grammar: Correct Grammar
#
# Sentence 4: ඔb diy naeemt gඟt yhi
# Grammar: Correct Grammar
#
# Sentence 5: thaepi diy naeemt gඟt yhu
# Grammar: Incorrect Grammar
#
# Sentence 6: thaopi diy naeemt gඟt yhu
# Grammar: Incorrect Grammar
#
# Sentence 7: nuඹla diy naeemt gඟt yhu
# Grammar: Incorrect Grammar
#
# Sentence 8: ඔb diy naeemt gඟt yhu
# Grammar: Incorrect Grammar
#
# Sentence 9: thaii sinhl giithayk gyhi
# Grammar: Correct Grammar
#
# Sentence 10: thaoo sinhl giithayk gyhi
# Grammar: Correct Grammar
#
# Sentence 11: nuඹ sinhl giithayk gyhi
# Grammar: Correct Grammar
#
# Sentence 12: ඔb sinhl giithayk gyhi
# Grammar: Correct Grammar
#
# Sentence 13: thaepi sinhl giithayk gyhu
# Grammar: Incorrect Grammar
#
# Sentence 14: thaopi sinhl giithayk gyhu
# Grammar: Incorrect Grammar
#
# Sentence 15: nuඹla sinhl giithayk gyhu
# Grammar: Incorrect Grammar
#
# Sentence 16: ඔb sinhl giithayk gyhu
# Grammar: Incorrect Grammar
#
# Sentence 17: thaii kwiyk gyhi
# Grammar: Correct Grammar
#
# Sentence 18: thaoo kwiyk gyhi
# Grammar: Correct Grammar
#
# Sentence 19: nuඹ kwiyk gyhi
# Grammar: Correct Grammar
#
# Sentence 20: ඔb kwiyk gyhi
# Grammar: Correct Grammar
#
# Sentence 21: thaepi kwiyk gyhu
# Grammar: Incorrect Grammar
#
# Sentence 22: thaopi kwiyk gyhu
# Grammar: Incorrect Grammar
#
# Sentence 23: nuඹla kwiyk gyhu
# Grammar: Incorrect Grammar
#
# Sentence 24: ඔb kwiyk gyhu
# Grammar: Incorrect Grammar
#
# Sentence 25: thaii k‍riida pitiyee k‍riida krhi
# Grammar: Correct Grammar
#
# Sentence 26: thaoo k‍riida pitiyee k‍riida krhi
# Grammar: Correct Grammar
#
# Sentence 27: nuඹ k‍riida pitiyee k‍riida krhi
# Grammar: Correct Grammar
#
# Sentence 28: ඔb k‍riida pitiyee k‍riida krhi
# Grammar: Correct Grammar
#
# Sentence 29: thaepi k‍riida pitiyee k‍riida krhu
# Grammar: Incorrect Grammar
#
# Sentence 30: thaopi k‍riida pitiyee k‍riida krhu
# Grammar: Incorrect Grammar
#
# Sentence 31: nuඹla k‍riida pitiyee k‍riida krhu
# Grammar: Incorrect Grammar
#
# Sentence 32: ඔb k‍riida pitiyee k‍riida krhu
# Grammar: Incorrect Grammar
#
# Sentence 33: thaii aadryen demwpiynt slkhi
# Grammar: Correct Grammar
#
# Sentence 34: thaoo aadryen demwpiynt slkhi
# Grammar: Correct Grammar
#
# Sentence 35: nuඹ aadryen demwpiynt slkhi
# Grammar: Correct Grammar
#
# Sentence 36: ඔb aadryen demwpiynt slkhi
# Grammar: Correct Grammar
#
# Sentence 37: thaepi aadryen demwpiynt slkhu
# Grammar: Incorrect Grammar
#
# Sentence 38: thaopi aadryen demwpiynt slkhu
# Grammar: Incorrect Grammar
#
# Sentence 39: nuඹla aadryen demwpiynt slkhu
# Grammar: Incorrect Grammar
#
# Sentence 40: ඔb aadryen demwpiynt slkhu
# Grammar: Incorrect Grammar
#
# Sentence 41: thaii potha padm krhi
# Grammar: Correct Grammar
#
# Sentence 42: thaoo potha padm krhi
# Grammar: Correct Grammar
#
# Sentence 43: nuඹ potha padm krhi
# Grammar: Correct Grammar
#
# Sentence 44: ඔb potha padm krhi
# Grammar: Correct Grammar
#
# Sentence 45: thaepi potha padm krhu
# Grammar: Incorrect Grammar
#
# Sentence 46: thaopi potha padm krhu
# Grammar: Incorrect Grammar
#
# Sentence 47: nuඹla potha padm krhu
# Grammar: Incorrect Grammar
#
# Sentence 48: ඔb potha padm krhu
# Grammar: Incorrect Grammar
#
# Sentence 49: thaii dinpthaa paslt yhi
# Grammar: Correct Grammar
#
# Sentence 50: thaoo dinpthaa paslt yhi
# Grammar: Correct Grammar
#
# Sentence 51: nuඹ dinpthaa paslt yhi
# Grammar: Correct Grammar
#
# Sentence 52: ඔb dinpthaa paslt yhi
# Grammar: Correct Grammar
#
# Sentence 53: thaepi dinpthaa paslt yhu
# Grammar: Incorrect Grammar
#
# Sentence 54: thaopi dinpthaa paslt yhu
# Grammar: Incorrect Grammar
#
# Sentence 55: nuඹla dinpthaa paslt yhu
# Grammar: Incorrect Grammar
#
# Sentence 56: ඔb dinpthaa paslt yhu
# Grammar: Incorrect Grammar
#
# Sentence 57: thaii weegyen ඔncili pdihi
# Grammar: Correct Grammar
#
# Sentence 58: thaoo weegyenඔncili pdihi
# Grammar: Correct Grammar
#
# Sentence 59: nuඹ weegyen ඔncili pdihi
# Grammar: Correct Grammar
#
# Sentence 60: ඔb weegyen ඔncili pdihi
# Grammar: Correct Grammar
#
# Sentence 61: thaepi weegyen ඔncili pdihu
# Grammar: Incorrect Grammar
#
# Sentence 62: thaopi weegyen ඔncili pdihu
# Grammar: Incorrect Grammar
#
# Sentence 63: nuඹla weegyenඔncili pdihu
# Grammar: Incorrect Grammar
#
# Sentence 64: ඔb weegyen ඔncili pdihu
# Grammar: Incorrect Grammar
#
# Sentence 65: thaii nuwr perhaer baeliimt yhi
# Grammar: Correct Grammar
#
# Sentence 66: thaoo nuwr perhaer baeliimt yhi
# Grammar: Correct Grammar
#
# Sentence 67: nuඹ nuwr perhaer baeliimt yhi
# Grammar: Correct Grammar
#
# Sentence 68: ඔb nuwr perhaer baeliimt yhi
# Grammar: Correct Grammar
#
# Sentence 69: thaepi nuwr perhaer baeliimt yhu
# Grammar: Incorrect Grammar
#
# Sentence 70: thaopi nuwr perhaer baeliimt yhu
# Grammar: Incorrect Grammar
#
# Sentence 71: nuඹla nuwr perhaer baeliimt yhu
# Grammar: Incorrect Grammar
#
# Sentence 72: ඔb nuwr perhaer baeliimt yhu
# Grammar: Incorrect Grammar
#
# Sentence 73: thaii dinpthaa pnslt yhi
# Grammar: Correct Grammar
#
# Sentence 74: thaoo dinpthaa pnslt yhi
# Grammar: Correct Grammar
#
# Sentence 75: nuඹ dinpthaa pnslt yhi
# Grammar: Correct Grammar
#
# Sentence 76: ඔb dinpthaa pnslt yhi
# Grammar: Correct Grammar
#
# Sentence 77: thaepi dinpthaa pnslt yhu
# Grammar: Incorrect Grammar
#
# Sentence 78: thaopi dinpthaa pnslt yhu
# Grammar: Incorrect Grammar
#
# Sentence 79: nuඹla dinpthaa pnslt yhu
# Grammar: Incorrect Grammar
#
# Sentence 80: ඔb dinpthaa pnslt yhu
# Grammar: Incorrect Grammar
#
# Sentence 81: thaii ithaa mihiri les giithayk gyhi
# Grammar: Correct Grammar
#
# Sentence 82: thaoo ithaa mihiri les giithayk gyhi
# Grammar: Correct Grammar
#
# Sentence 83: nuඹ ithaa mihiri les giithayk gyhi
# Grammar: Correct Grammar
#
# Sentence 84: ඔb ithaa mihiri les giithayk gyhi
# Grammar: Correct Grammar
#
# Sentence 85: thaepi ithaa mihiri les giithayk gyhu
# Grammar: Incorrect Grammar
#
# Sentence 86: thaopi ithaa mihiri les giithayk gyhu
# Grammar: Incorrect Grammar
#
# Sentence 87: nuඹla ithaa mihiri les giithayk gyhu
# Grammar: Incorrect Grammar
#
# Sentence 88: ඔb ithaa mihiri les giithayk gyhu
# Grammar: Incorrect Grammar
#
# Sentence 89: thaii lssn giithaykt nthi
# Grammar: Correct Grammar
#
# Sentence 90: thaoo lssn giithaykt nthi
# Grammar: Correct Grammar
#
# Sentence 91: nuඹ lssn giithaykt nthi
# Grammar: Correct Grammar
#
# Sentence 92: ඔb lssn giithaykt nthi
# Grammar: Correct Grammar
#
# Sentence 93: thaepi lssn giithaykt nthu
# Grammar: Incorrect Grammar
#
# Sentence 94: thaopi lssn giithaykt nthu
# Grammar: Incorrect Grammar
#
# Sentence 95: nuඹla lssn giithaykt nthu
# Grammar: Incorrect Grammar
#
# Sentence 96: ඔb lssn giithaykt nthu
# Grammar: Incorrect Grammar
#
# Sentence 97: thaii dinpthaa raekiyawt yhi
# Grammar: Correct Grammar
#
# Sentence 98: thaoo dinpthaa raekiyawt yhi
# Grammar: Correct Grammar
#
# Sentence 99: nuඹ dinpthaa raekiyawt yhi
# Grammar: Correct Grammar
#
# Sentence 100: ඔb dinpthaa raekiyawt yhi
# Grammar: Correct Grammar
#
# Sentence 101: thaepi dinpthaa raekiyawt yhu
# Grammar: Incorrect Grammar
#
# Sentence 102: thaopi dinpthaa raekiyawt yhu
# Grammar: Incorrect Grammar
#
# Sentence 103: nuඹla dinpthaa raekiyawt yhu
# Grammar: Incorrect Grammar
#
# Sentence 104: ඔb dinpthaa raekiyawt yhu
# Grammar: Incorrect Grammar
#
# Sentence 105: yuෂmthaa boru kiyhi
# Grammar: Correct Grammar
#
# Sentence 106: yuෂmthaiy boru kiyhi
# Grammar: Correct Grammar
#
# Sentence 107: yuෂmthahu boru kiyhu
# Grammar: Incorrect Grammar
#
# Sentence 108: yuෂmthaa karyy awsn krhi
# Grammar: Correct Grammar
#
# Sentence 109: yuෂmthaiy karyy awsn krhi
# Grammar: Correct Grammar
#
# Sentence 110: yuෂmthahu karyy awsn krhu
# Grammar: Incorrect Grammar
#
# Number of Correct Grammar Sentences: 56
# Number of Incorrect Grammar Sentences: 53

# %% [markdown]
# ## For "Nubala,Obala" Sentence

# %%
input_text = joined_rows
letter_comb = "හු"

# %%
# Convert Sinhala letters to English
english_text = sinhala_to_english(input_text)
print("Input Text in Sinhala:")
print(input_text)
print("\nConverted to English Letters:")
print(english_text)

start_text = sinhala_to_english(letter_comb)
print("\nConverted Starting Letter:")
print(start_text)


def count_correct_grammar_sentences(english_text, start_text):
    # Check grammar using the previous code
    results = check_grammar(english_text, start_text)

    correct_grammar_count = results.count("Correct Grammar")
    incorrect_grammar_count = results.count("Incorrect Grammar")

    return correct_grammar_count, incorrect_grammar_count


# Check grammar using the previous code
results = check_grammar(english_text, start_text)
print("\nGrammar Check Results:")
sentences = english_text.split('.')
for i, sentence in enumerate(sentences):
    print(f"Sentence {i + 1}: {sentence.strip()}")
    print(f"Grammar: {results[i]}\n")

# Example usage:
correct_grammar_count, incorrect_grammar_count = count_correct_grammar_sentences(english_text, start_text)

print(f"Number of Correct Grammar Sentences: {correct_grammar_count}")
print(f"Number of Incorrect Grammar Sentences: {incorrect_grammar_count - 1}")
# Out:
# Input Text in Sinhala:
# ﻿තී දිය නෑමට ගඟට යහි.තෝ  දිය නෑමට ගඟට යහි.නුඹ දිය නෑමට ගඟට යහි.ඔබ දිය නෑමට ගඟට යහි.තෙපි දිය නෑමට ගඟට යහු.තොපි දිය නෑමට ගඟට යහු.නුඹලා දිය නෑමට ගඟට යහු.ඔබ දිය නෑමට ගඟට යහු.තී සිංහල ගීතයක් ගයහි.තෝ සිංහල ගීතයක් ගයහි.නුඹ සිංහල ගීතයක් ගයහි.ඔබ සිංහල ගීතයක් ගයහි.තෙපි සිංහල ගීතයක් ගයහු.තොපි සිංහල ගීතයක් ගයහු.නුඹලා සිංහල ගීතයක් ගයහු.ඔබ සිංහල ගීතයක් ගයහු.තී කවියක් ගයහි.තෝ කවියක් ගයහි.නුඹ කවියක් ගයහි.ඔබ කවියක් ගයහි.තෙපි කවියක් ගයහු.තොපි කවියක් ගයහු.නුඹලා කවියක් ගයහු.ඔබ කවියක් ගයහු.තී ක්‍රීඩා පිටියේ ක්‍රීඩා කරහි.තෝ ක්‍රීඩා පිටියේ ක්‍රීඩා කරහි.නුඹ ක්‍රීඩා පිටියේ ක්‍රීඩා කරහි.ඔබ ක්‍රීඩා පිටියේ ක්‍රීඩා කරහි.තෙපි ක්‍රීඩා පිටියේ ක්‍රීඩා කරහු.තොපි ක්‍රීඩා පිටියේ ක්‍රීඩා කරහු.නුඹලා ක්‍රීඩා පිටියේ ක්‍රීඩා කරහු.ඔබ ක්‍රීඩා පිටියේ ක්‍රීඩා කරහු.තී ආදරයෙන් දෙමව්පියන්ට සලකහි.තෝ ආදරයෙන් දෙමව්පියන්ට සලකහි.නුඹ ආදරයෙන් දෙමව්පියන්ට සලකහි.ඔබ ආදරයෙන් දෙමව්පියන්ට සලකහි.තෙපි ආදරයෙන් දෙමව්පියන්ට සලකහු.තොපි ආදරයෙන් දෙමව්පියන්ට සලකහු.නුඹලා ආදරයෙන් දෙමව්පියන්ට සලකහු.ඔබ ආදරයෙන් දෙමව්පියන්ට සලකහු.තී පොත් පාඩම් කරහි.තෝ පොත් පාඩම් කරහි.නුඹ පොත් පාඩම් කරහි.ඔබ පොත් පාඩම් කරහි.තෙපි පොත් පාඩම් කරහු.තොපි පොත් පාඩම් කරහු.නුඹලා පො
ithaa mihiri les giithayk gyhu.thaii lssn giithaykt nthi.thaoo lssn giithaykt nthi.nuඹ lssn giithaykt nthi.ඔb lssn giithaykt nthi.thaepi lssn giithaykt nthu.thaopi lssn giithaykt nthu.nuඹla lssn giithaykt nthu.ඔb lssn giithaykt nthu.thaii dinpthaa raekiyawt yhi.thaoo dinpthaa raekiyawt yhi.nuඹ dinpthaa raekiyawt yhi.ඔb dinpthaa raekiyawt yhi.thaepi dinpthaa raekiyawt yhu.thaopi dinpthaa raekiyawt yhu.nuඹla dinpthaa raekiyawt yhu.ඔb dinpthaa raekiyawt yhu.yuෂmthaa boru kiyhi.yuෂmthaiy boru kiyhi.yuෂmthahu boru kiyhu.yuෂmthaa karyy awsn krhi.yuෂmthaiy karyy awsn krhi.yuෂmthahu karyy awsn krhu
#
# Converted Starting Letter:
# hu
#
# Grammar Check Results:
# Sentence 1: ﻿thaii diy naeemt gඟt yhi
# Grammar: Incorrect Grammar
#
# Sentence 2: thaoo  diy naeemt gඟt yhi
# Grammar: Incorrect Grammar
#
# Sentence 3: nuඹ diy naeemt gඟt yhi
# Grammar: Incorrect Grammar
#
# Sentence 4: ඔb diy naeemt gඟt yhi
# Grammar: Incorrect Grammar
#
# Sentence 5: thaepi diy naeemt gඟt yhu
# Grammar: Correct Grammar
#
# Sentence 6: thaopi diy naeemt gඟt yhu
# Grammar: Correct Grammar
#
# Sentence 7: nuඹla diy naeemt gඟt yhu
# Grammar: Correct Grammar
#
# Sentence 8: ඔb diy naeemt gඟt yhu
# Grammar: Correct Grammar
#
# Sentence 9: thaii sinhl giithayk gyhi
# Grammar: Incorrect Grammar
#
# Sentence 10: thaoo sinhl giithayk gyhi
# Grammar: Incorrect Grammar
#
# Sentence 11: nuඹ sinhl giithayk gyhi
# Grammar: Incorrect Grammar
#
# Sentence 12: ඔb sinhl giithayk gyhi
# Grammar: Incorrect Grammar
#
# Sentence 13: thaepi sinhl giithayk gyhu
# Grammar: Correct Grammar
#
# Sentence 14: thaopi sinhl giithayk gyhu
# Grammar: Correct Grammar
#
# Sentence 15: nuඹla sinhl giithayk gyhu
# Grammar: Correct Grammar
#
# Sentence 16: ඔb sinhl giithayk gyhu
# Grammar: Correct Grammar
#
# Sentence 17: thaii kwiyk gyhi
# Grammar: Incorrect Grammar
#
# Sentence 18: thaoo kwiyk gyhi
# Grammar: Incorrect Grammar
#
# Sentence 19: nuඹ kwiyk gyhi
# Grammar: Incorrect Grammar
#
# Sentence 20: ඔb kwiyk gyhi
# Grammar: Incorrect Grammar
#
# Sentence 21: thaepi kwiyk gyhu
# Grammar: Correct Grammar
#
# Sentence 22: thaopi kwiyk gyhu
# Grammar: Correct Grammar
#
# Sentence 23: nuඹla kwiyk gyhu
# Grammar: Correct Grammar
#
# Sentence 24: ඔb kwiyk gyhu
# Grammar: Correct Grammar
#
# Sentence 25: thaii k‍riida pitiyee k‍riida krhi
# Grammar: Incorrect Grammar
#
# Sentence 26: thaoo k‍riida pitiyee k‍riida krhi
# Grammar: Incorrect Grammar
#
# Sentence 27: nuඹ k‍riida pitiyee k‍riida krhi
# Grammar: Incorrect Grammar
#
# Sentence 28: ඔb k‍riida pitiyee k‍riida krhi
# Grammar: Incorrect Grammar
#
# Sentence 29: thaepi k‍riida pitiyee k‍riida krhu
# Grammar: Correct Grammar
#
# Sentence 30: thaopi k‍riida pitiyee k‍riida krhu
# Grammar: Correct Grammar
#
# Sentence 31: nuඹla k‍riida pitiyee k‍riida krhu
# Grammar: Correct Grammar
#
# Sentence 32: ඔb k‍riida pitiyee k‍riida krhu
# Grammar: Correct Grammar
#
# Sentence 33: thaii aadryen demwpiynt slkhi
# Grammar: Incorrect Grammar
#
# Sentence 34: thaoo aadryen demwpiynt slkhi
# Grammar: Incorrect Grammar
#
# Sentence 35: nuඹ aadryen demwpiynt slkhi
# Grammar: Incorrect Grammar
#
# Sentence 36: ඔb aadryen demwpiynt slkhi
# Grammar: Incorrect Grammar
#
# Sentence 37: thaepi aadryen demwpiynt slkhu
# Grammar: Correct Grammar
#
# Sentence 38: thaopi aadryen demwpiynt slkhu
# Grammar: Correct Grammar
#
# Sentence 39: nuඹla aadryen demwpiynt slkhu
# Grammar: Correct Grammar
#
# Sentence 40: ඔb aadryen demwpiynt slkhu
# Grammar: Correct Grammar
#
# Sentence 41: thaii potha padm krhi
# Grammar: Incorrect Grammar
#
# Sentence 42: thaoo potha padm krhi
# Grammar: Incorrect Grammar
#
# Sentence 43: nuඹ potha padm krhi
# Grammar: Incorrect Grammar
#
# Sentence 44: ඔb potha padm krhi
# Grammar: Incorrect Grammar
#
# Sentence 45: thaepi potha padm krhu
# Grammar: Correct Grammar
#
# Sentence 46: thaopi potha padm krhu
# Grammar: Correct Grammar
#
# Sentence 47: nuඹla potha padm krhu
# Grammar: Correct Grammar
#
# Sentence 48: ඔb potha padm krhu
# Grammar: Correct Grammar
#
# Sentence 49: thaii dinpthaa paslt yhi
# Grammar: Incorrect Grammar
#
# Sentence 50: thaoo dinpthaa paslt yhi
# Grammar: Incorrect Grammar
#
# Sentence 51: nuඹ dinpthaa paslt yhi
# Grammar: Incorrect Grammar
#
# Sentence 52: ඔb dinpthaa paslt yhi
# Grammar: Incorrect Grammar
#
# Sentence 53: thaepi dinpthaa paslt yhu
# Grammar: Correct Grammar
#
# Sentence 54: thaopi dinpthaa paslt yhu
# Grammar: Correct Grammar
#
# Sentence 55: nuඹla dinpthaa paslt yhu
# Grammar: Correct Grammar
#
# Sentence 56: ඔb dinpthaa paslt yhu
# Grammar: Correct Grammar
#
# Sentence 57: thaii weegyen ඔncili pdihi
# Grammar: Incorrect Grammar
#
# Sentence 58: thaoo weegyenඔncili pdihi
# Grammar: Incorrect Grammar
#
# Sentence 59: nuඹ weegyen ඔncili pdihi
# Grammar: Incorrect Grammar
#
# Sentence 60: ඔb weegyen ඔncili pdihi
# Grammar: Incorrect Grammar
#
# Sentence 61: thaepi weegyen ඔncili pdihu
# Grammar: Correct Grammar
#
# Sentence 62: thaopi weegyen ඔncili pdihu
# Grammar: Correct Grammar
#
# Sentence 63: nuඹla weegyenඔncili pdihu
# Grammar: Correct Grammar
#
# Sentence 64: ඔb weegyen ඔncili pdihu
# Grammar: Correct Grammar
#
# Sentence 65: thaii nuwr perhaer baeliimt yhi
# Grammar: Incorrect Grammar
#
# Sentence 66: thaoo nuwr perhaer baeliimt yhi
# Grammar: Incorrect Grammar
#
# Sentence 67: nuඹ nuwr perhaer baeliimt yhi
# Grammar: Incorrect Grammar
#
# Sentence 68: ඔb nuwr perhaer baeliimt yhi
# Grammar: Incorrect Grammar
#
# Sentence 69: thaepi nuwr perhaer baeliimt yhu
# Grammar: Correct Grammar
#
# Sentence 70: thaopi nuwr perhaer baeliimt yhu
# Grammar: Correct Grammar
#
# Sentence 71: nuඹla nuwr perhaer baeliimt yhu
# Grammar: Correct Grammar
#
# Sentence 72: ඔb nuwr perhaer baeliimt yhu
# Grammar: Correct Grammar
#
# Sentence 73: thaii dinpthaa pnslt yhi
# Grammar: Incorrect Grammar
#
# Sentence 74: thaoo dinpthaa pnslt yhi
# Grammar: Incorrect Grammar
#
# Sentence 75: nuඹ dinpthaa pnslt yhi
# Grammar: Incorrect Grammar
#
# Sentence 76: ඔb dinpthaa pnslt yhi
# Grammar: Incorrect Grammar
#
# Sentence 77: thaepi dinpthaa pnslt yhu
# Grammar: Correct Grammar
#
# Sentence 78: thaopi dinpthaa pnslt yhu
# Grammar: Correct Grammar
#
# Sentence 79: nuඹla dinpthaa pnslt yhu
# Grammar: Correct Grammar
#
# Sentence 80: ඔb dinpthaa pnslt yhu
# Grammar: Correct Grammar
#
# Sentence 81: thaii ithaa mihiri les giithayk gyhi
# Grammar: Incorrect Grammar
#
# Sentence 82: thaoo ithaa mihiri les giithayk gyhi
# Grammar: Incorrect Grammar
#
# Sentence 83: nuඹ ithaa mihiri les giithayk gyhi
# Grammar: Incorrect Grammar
#
# Sentence 84: ඔb ithaa mihiri les giithayk gyhi
# Grammar: Incorrect Grammar
#
# Sentence 85: thaepi ithaa mihiri les giithayk gyhu
# Grammar: Correct Grammar
#
# Sentence 86: thaopi ithaa mihiri les giithayk gyhu
# Grammar: Correct Grammar
#
# Sentence 87: nuඹla ithaa mihiri les giithayk gyhu
# Grammar: Correct Grammar
#
# Sentence 88: ඔb ithaa mihiri les giithayk gyhu
# Grammar: Correct Grammar
#
# Sentence 89: thaii lssn giithaykt nthi
# Grammar: Incorrect Grammar
#
# Sentence 90: thaoo lssn giithaykt nthi
# Grammar: Incorrect Grammar
#
# Sentence 91: nuඹ lssn giithaykt nthi
# Grammar: Incorrect Grammar
#
# Sentence 92: ඔb lssn giithaykt nthi
# Grammar: Incorrect Grammar
#
# Sentence 93: thaepi lssn giithaykt nthu
# Grammar: Correct Grammar
#
# Sentence 94: thaopi lssn giithaykt nthu
# Grammar: Correct Grammar
#
# Sentence 95: nuඹla lssn giithaykt nthu
# Grammar: Correct Grammar
#
# Sentence 96: ඔb lssn giithaykt nthu
# Grammar: Correct Grammar
#
# Sentence 97: thaii dinpthaa raekiyawt yhi
# Grammar: Incorrect Grammar
#
# Sentence 98: thaoo dinpthaa raekiyawt yhi
# Grammar: Incorrect Grammar
#
# Sentence 99: nuඹ dinpthaa raekiyawt yhi
# Grammar: Incorrect Grammar
#
# Sentence 100: ඔb dinpthaa raekiyawt yhi
# Grammar: Incorrect Grammar
#
# Sentence 101: thaepi dinpthaa raekiyawt yhu
# Grammar: Correct Grammar
#
# Sentence 102: thaopi dinpthaa raekiyawt yhu
# Grammar: Correct Grammar
#
# Sentence 103: nuඹla dinpthaa raekiyawt yhu
# Grammar: Correct Grammar
#
# Sentence 104: ඔb dinpthaa raekiyawt yhu
# Grammar: Correct Grammar
#
# Sentence 105: yuෂmthaa boru kiyhi
# Grammar: Incorrect Grammar
#
# Sentence 106: yuෂmthaiy boru kiyhi
# Grammar: Incorrect Grammar
#
# Sentence 107: yuෂmthahu boru kiyhu
# Grammar: Correct Grammar
#
# Sentence 108: yuෂmthaa karyy awsn krhi
# Grammar: Incorrect Grammar
#
# Sentence 109: yuෂmthaiy karyy awsn krhi
# Grammar: Incorrect Grammar
#
# Sentence 110: yuෂmthahu karyy awsn krhu
# Grammar: Correct Grammar
#
# Number of Correct Grammar Sentences: 54
# Number of Incorrect Grammar Sentences: 55
