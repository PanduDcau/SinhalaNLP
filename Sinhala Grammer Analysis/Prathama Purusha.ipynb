# %% [markdown]
# ### Prathama Purusha (Third Person)

# %%
def sinhala_to_english(text):
    # Define a mapping dictionary for Sinhalese to English letters
    sinhala_to_english_mapping = {
        'ම': 'm', 'අ': 'a', 'ද': 'd', 'ග': 'g', 'ෙ': 'e',
        'හ': 'h', 'ප': 'p', 'බ': 'b',
        'ඉ': 'i', 'න': 'n', 'ට': 't', 'ත': 'tha',
        'ච': 'c', 'එ': 'e', 'ය': 'y', 'ල': 'l', 'ව': 'w',
        'ැ': 'ae', 'ළ': 'l', 'ආ': 'aa', 'ං': 'n',
        'ර': 'r', 'ජ': 'j', 'ස': 's', 'ෆ': 'f', 'භ': 'b',
        'ය': 'y', 'ි': 'i', 'ක': 'k',
        'ො': 'o', 'ඩ': 'd', '්': '', ' ': ' ', '.': '.',
        'ා': 'a', 'ැ': 'ae', 'ෑ': 'aee', 'ි': 'i', 'ී': 'ii',
        'ු': 'u', 'ූ': 'uu', 'ෘ': 'u', 'ෙ': 'e', 'ේ': 'ee',
        'ෛ': 'ei', 'ෝ': 'oo', 'ෞ': 'ou',
        'ෟ': 'o', 'ෲ': 'lu', 'ෳ': 'lu'
    }

    # Perform the conversion
    english_text = ""
    for char in text:
        if char in sinhala_to_english_mapping:
            english_text += sinhala_to_english_mapping[char]
        else:
            english_text += char

    return english_text

# %%
import re
def check_grammar(text, letter_combination):
    # Split the text into sentences
    sentences = text.split('.')

    results = []

    for sentence in sentences:
        # Split each sentence into words
        words = sentence.split()

        # Check if there are at least two words in the sentence
        if len(words) >= 1:
            last_word = words[-1].strip(".,!?")

            # Check if the last two letters of the last word match the specified letter combination
            if last_word[-2:].lower() == letter_combination.lower():
                results.append("Correct Grammar")
            else:
                results.append("Incorrect Grammar")
        else:
            # If there are no words in the sentence, it's considered incorrect grammar
            results.append("Incorrect Grammar")

    return results

# %%
import csv

# Provide a valid file path for your CSV file
# Specify the encoding that matches your CSV file

file_encoding = 'utf-8'  # You can change this to 'latin-1' or other encodings if needed
csv_file_path = "ThirdPerson-PresentTense.csv"  # Replace with the path to your CSV file

all_rows = []  # List to store all rows as strings

with open(csv_file_path, 'r', newline='', encoding=file_encoding) as csvfile:
    csv_reader = csv.reader(csvfile)

    for row in csv_reader:
        if row:  # Check if the row is not empty
            # Combine the row's elements into a single string separated by dots
            row_string = '.'.join(row)
            all_rows.append(row_string)

# %%
joined_rows = '.'.join(all_rows)

# %%
all_rows
# Out:
# ['\ufeffතාත්තා මිදුලේ සිටියි',
#  'තාත්තා එළවළු පාත්තිවලට පොහොර දමයි',
#  'අම්මා කුස්සියේ සිටියි',
#  'අම්මා රස කෑමක් සාදයි',
#  'මල්ලී මිදුලේ සෙල්ලම් කරයි',
#  'නංගී මිදුලේ සෙල්ලම් කරයි',
#  'සිංහයා ගස යට සිටියි',
#  'වෛද්\u200dයතුමා රෝගියාට බෙහෙත් දෙයි',
#  'වෛද්\u200dයතුමිය රෝගියාට බෙහෙත් දෙයි',
#  'වෛද්\u200dයතුමා රෝගියාට කරුණාවෙන් සවන් දෙයි',
#  'වෛද්\u200dයතුමිය රෝගියාට කරුණාවෙන් කතා කරයි',
#  'සමනලයා මල් පැණි බොයි',
#  'ලේනා ගස් උඩ පැන පැන නටයි',
#  'ගායිකාව මිහිරි ගීතයක් ගයයි',
#  'ගුරුවරිය පාඩම් කියා දෙයි',
#  'අක්කා ශබ්ද නගා පාඩම් කරයි',
#  'ගොවියා උදෑසනින් කුඹුරට යයි',
#  'කුරුල්ලා අහසේ පියාඹයි',
#  'ඔහු ගසට නැග පේර කඩයි',
#  'හේ මහ පාර අසලට වී සිටියි',
#  'හෙතෙම පයින් ම නගරයට යයි',
#  'තාත්තා පොරව ගෙන කොටය පළයි',
#  'මාමා උදැල්ල ගෙන වල් කොටයි',
#  'ගොනා ළපටි තණකොළ කයි',
#  'බල්ලා අහසට උඩු බුරයි',
#  'හාවා වේගයෙන් පැන පැන යයි',
#  'තාරාවා වැව් ජලයේ වේගයෙන් පීනයි',
#  'ගොවියා කෙතට බැස ගොයම් කපයි',
#  'ඇය රැකියාව බලා පිටත් වෙයි',
#  'බල්ලා වේගයෙන් දුවයි',
#  'අම්මා දිවා ආහාර පිසින්නීය',
#  'අක්කා තාලයට නටන්නීය',
#  'නැන්දා යහපත් වැඩ කරන්නීය',
#  'නැන්දා යහපත් වැඩ කරයි',
#  'ගෙවිළිය කෙතට බැස ගොයම් කපන්නීය',
#  'ගෙවිළිය කෙතට බැස ගොයම් කපයි',
#  'අම්මා දිවා ආහාර පිසියි',
#  'අක්කා තාලයට නටයි',
#  'එළදෙන තණකොළ කන්නීය',
#  'එළදෙන තණකොළ කයි',
#  'අම්මා රසවත් ආහාර සකසයි',
#  'තාත්තා දිනපතා රැකියාවට යයි',
#  'අක්කා ලස්සන ගවුමක් මසමින් සිටියි',
#  'කුරුල්ලා අඹ ගස මුදුණේ සිටියි',
#  'පූසා මිදුල පුරා දුවමින් සෙල්ලම් කරයි',
#  'මල්ලී මිදුල පුරා දුවමින් සෙල්ලම් කරයි',
#  'නංගී මිදුල පුරා දුවමින් සෙල්ලම් කරයි',
#  'බල්ලා මිදුල පුරා දුවමින් සෙල්ලම් කරයි',
#  'ගුරුතුමා ගණිතය පාඩම උගන්වයි',
#  'විදුහල්පතිතුමා පාසලට වේලාසනින් පැමිණෙයි',
#  'විදුහල්පතිතුමිය පාසලට වේලාසනින් පැමිණෙයි',
#  'කුරුල්ලා ගස මුදුණේ කූඩුවක් තනයි',
#  'ගායකයා මිහිරි ගීතයක් ගායනා කරයි',
#  'ගුරුවරයා ළමයින්ට පාඩම් කියා දෙයි',
#  'අයියා ශබ්ද නගා පාඩම් කරයි',
#  'ගෙවිළිය උදෑසනින් කුඹුරට යයි',
#  'උකුස්සා අහසේ පියා සරයි',
#  'ඇය ගසට නැග පේර කඩයි',
#  'හේ පන්සල අසලට වී සිටියි',
#  'හෙතෙම පයින් ම නිවස බලා යයි',
#  'අම්මා පොරව ගෙන කොටය පළයි',
#  'අයියා උදැල්ල ගෙන වල් කොටයි',
#  'ගවයා ළපටි තණකොළ කයි',
#  'බල්ලා වේගයෙන් දුවමින් සෙල්ලම් කරයි',
#  'කැන්ගරුවා වේගයෙන් පැන පැන යයි',
#  'මල්ලී වැව් ජලයේ වේගයෙන් පීනයි',
#  'ගෙවිළිය කෙතට බැස ගොයම් කපයි',
#  'ඔහු රැකියාව බලා පිටත් වෙයි',
#  'මල්ලී වේගයෙන් වතුරේ පීනයි',
#  'අක්කා දිවා ආහාර පිසින්නීය',
#  'අක්කා ගීතයකට ලස්සනට නටන්නීය',
#  'නැන්දා යහපත් වැඩ කියා දෙන්නීය',
#  'නැන්දා යහපත් වැඩ කියා දෙයි',
#  'ගොවියා කෙතට බැස ගොයම් කපයි',
#  'ගෙවිළිය කෙතට බැස ගොයම් සිටවයි',
#  'අක්කා ගීතයකට ලස්සනට නටයි',
#  'අක්කා තාලයට අත්පුඩි ගසයි',
#  'මගියා බසයට නැග සිට ගනියි',
#  'තොටියා ඔරුව දියත් කරමින් සිටියි',
#  'පාලකයා රට පාලනය කරයි',
#  'මුවා කැළය මැදින් ගමන් කරයි',
#  'අලියා වැවෙන් දිය බොයි',
#  'කූඹියා ශීත කාලයට කෑම රැස් කරයි',
#  'අක්කා උදෑසනින් ම අවදි වෙයි',
#  'ළමයා උදෑසනින් ම අවදි වී පාසලට යයි',
#  'ඔහු නිවැරදි ව අකුරු ලියයි',
#  'ඇය නිවැරදි ව අකුරු ලියයි',
#  'ඇය නිවැරදි ව අකුරු ලියන්නීය',
#  'ඔහු ලස්සන ගීතයක් ගායනා කරයි',
#  'ඇය ලස්සන ගීතයක් ගායනා කරයි',
#  'ඇය ලස්සන ගීතයක් ගායනා කරන්නීය',
#  'නරියා කැළය මැදින් ගමන් කරයි',
#  'සිංහයා කැළය මැදින් ගමන් කරයි',
#  'කොටියා කැළය මැදින් ගමන් කරයි',
#  'අයියා උදෑසනින් ම අවදි වී රැකියාවට යයි',
#  'මාමා උදෑසනින් ම අවදි වී රැකියාවට යයි',
#  'ක්\u200dරීඩකයා ක්\u200dරීඩා පිටියට පැමිණෙයි',
#  'යෙහෙළිය සෙල්ලම් කිරීමට පිටියට පැමිණෙයි',
#  'සීයා මිදුලේ අඹ පැළයක් සිටුවයි',
#  'ආච්චි පෝයට සිල් ගැනීමට පන්සලට යයි',
#  'ගස ඉතා වේගයෙන් සෙලවෙයි',
#  'සරුංගලය අහසේ පාවී පාවී තිබෙයි',
#  'නැව සයුරේ යාත්\u200dරා කරමින් සිටියි',
#  'තාරකාව දීප්තිමත්ව අහසේ බැබළෙයි',
#  'ගස සුළඟට ඉදිරී වැටෙයි',
#  'ගංගාව මුහුදට සීරුවෙන් ගලා බසියි',
#  'මල පරවී බිම වැටෙයි',
#  'නිවස ජල ගැල්මට හසු වී යට වෙයි',
#  'උදෑසනම ලස්සන මලක් පිපෙයි',
#  'ඉහළ අහසේ සරුංගලයක් පාවෙයි',
#  'බෝලය කන්දෙන් පහළට පෙරලෙයි',
#  'කොළය වේගයෙන් සුළඟට ගසාගෙන යයි',
#  'රාත්\u200dරී අහසේ ලස්සන තරුවක් පායයි',
#  'ගුවන්විදුලි යන්ත්\u200dරය ක්\u200dරියාත්මක වෙයි',
#  'රූපවාහිනී යන්ත්\u200dරය ක්\u200dරියාත්මක වෙමින් තිබෙයි',
#  'තාත්තලා මිදුලේ සිටිති',
#  'තාත්තලා එළවළු පාත්තිවලට පොහොර දමති',
#  'අම්මලා කුස්සියේ සිටිති',
#  'අම්මලා රස කෑමක් සාදති',
#  'මල්ලිලා මිදුලේ සෙල්ලම් කරති',
#  'නංගිලා මිදුලේ සෙල්ලම් කරති',
#  'සිංහයෝ ගස යට නිදති',
#  'වෛද්\u200dයවරු රෝගියාට බෙහෙත් දෙති',
#  'වෛද්\u200dයවරියෝ රෝගියාට බෙහෙත් දෙති',
#  'වෛද්\u200dයවරු රෝගීන්ට කරුණාවෙන් සවන් දෙති',
#  'වෛද්\u200dයවරියෝ රෝගීන්ට කරුණාවෙන් කතා  කරති',
#  'සමනලයෝ මල් පැණි බොති',
#  'කුරුල්ලෝ ගස් උඩ පැන පැන නටති',
#  'ගායිකාවෝ මිහිරි ගීතයක් ගයති',
#  'ගුරුවරු පාඩම් කියා දෙති',
#  'අක්කලා ශබ්ද නගා පාඩම් කරති',
#  'ගොවියෝ උදෑසනින් කුඹුරට යති',
#  'කුරුල්ලෝ අහසේ පියාඹති',
#  'ඔවුහු ගසට නැග පේර කඩති',
#  'ඔවුහු මහ පාර අසලට වී සිටිති',
#  'ඔවුහු පයින් ම නගරයට යති',
#  'තාත්තලා කැළයට ගොස් ගස් කපති',
#  'මාමලා උදලු ගෙන වල් කොටති',
#  'ගවයෝ ළපටි තණකොළ කති',
#  'බල්ලෝ අහසට උඩු බුරති',
#  'හාවෝ වේගයෙන් පැන පැන යති',
#  'තාරාවෝ වැව් ජලයේ වේගයෙන් පීනති',
#  'ගොවියෝ කෙතට බැස ගොයම් කපති',
#  'ඔවුහු රැකියාවන් බලා පිටත් වෙති',
#  'බල්ලෝ වේගයෙන් පාරේ දුවති',
#  'අම්මලා වෙහෙස වී දිවා ආහාර පිසිති',
#  'අක්කලා තාලයට පාද තබමින් නටති',
#  'නැන්දලා යහපත් වැඩ කරති',
#  'නැන්දලා රෙදි සෝ දමින් සිටිති',
#  'ගෙවිළියෝ කෙතට බැස ගොයම් කපති',
#  'ගෙවිළියෝ කෙතට බැස ගොයම් සිටුවති',
#  'අම්මලා රසවත් ආහාර පිසිති',
#  'අක්කලා තාලයට ගීත කියති',
#  'එළදෙන්නු පිට්ටනියේ තණකොළ කති',
#  'එළදෙන්නු පිට්ටනියේ තණකොළ කමින් සිටිති',
#  'අම්මලා රසවත් ආහාර සකසමින් සිටිති',
#  'තාත්තලා දිනපතා රැකියාවට යති',
#  'අක්කලා ලස්සන ගවුම් මසමින් සිටිති',
#  'කුරුල්ලෝ අඹ ගස මුදුණේ සිටිති',
#  'පූසෝ මිදුල පුරා දුවමින් සෙල්ලම් කරති',
#  'මල්ලිලා මිදුල පුරා දුවමින් සෙල්ලම් කරති',
#  'නංගිලා මිදුල පුරා දුවමින් සෙල්ලම් කරති',
#  'බල්ලෝ මිදුල පුරා දුවමින් සෙල්ලම් කරති',
#  'ගුරුවරු ගණිතය පාඩම් නිවැරදිව උගන්වති',
#  'ගුරුවරු පාසලට වේලාසනින් පැමිණෙති',
#  'විදුහල්පතිවරු පාසලට වේලාසනින් පැමිණෙති',
#  'කුරුල්ලෝ ගස මුදුණේ කූඩුවක් තනති',
#  'ගායකයෝ මිහිරි ගීතයක් ගායනා  කරති',
#  'ගුරුවරු ළමයින්ට පාඩම් කියා දෙති',
#  'අයියලා ශබ්ද නගා පාඩම් කරති',
#  'ගෙවිළියෝ උදෑසනින් කුඹුරට යති',
#  'උකුස්සෝ අහසේ පියාසරති',
#  'ඔවුහු ගසට නැග අඹ කඩති',
#  'ඔවුහු පාසල අසලට වී සිටිති',
#  'ඔවුහු පයින් ම පන්සල බලා යති',
#  'අම්මලා උදලු ගෙන පොළොව කොටති',
#  'අයියලා උදලු ගෙන වල් කොටති',
#  'ගවයෝ ළපටි තණකොළ කති',
#  'බල්ලෝ වේගයෙන් දුවමින් සෙල්ලම් කරති',
#  'කැන්ගරුවෝ වේගයෙන් පැන පැන යති',
#  'මල්ලිලා වැව් ජලයේ වේගයෙන් පීනති',
#  'ගොවියෝ කෙතට බැස ගොයම් සිටුවති',
#  'ඔවුහු රාජකාරී බලා පිටත් වෙති',
#  'මල්ලිලා වේගයෙන් වතුරේ පීනති',
#  'අක්කලා දිවා ආහාර පිසිති',
#  'අක්කලා ගීතයකට ලස්සනට නටති',
#  'නැන්දලා යහපත් වැඩ කියා දෙති',
#  'නැන්දලා යහපත් වැඩවලට යොමු කරති',
#  'ගොවියෝ කෙතට බැස වී ඉසිති',
#  'ගෙවිළියෝ කෙතට බැස ගොයම් පාගති',
#  'අක්කලා ගීතයකට ලස්සනට නර්තනයේ යෙදෙති',
#  'අක්කලා තාලයට අත්පුඩි ගසති',
#  'මගියෝ බසයට නැග සිට ගනිති',
#  'තොටියෝ ඔරුව දියත් කරමින් සිටිති',
#  'පාලකයෝ රට පාලනය කරති',
#  'සත්තු කැළය මැදින් ගමන් කරති',
#  'අලි වැවෙන් දිය බොති',
#  'කූඹි ශීත කාලයට කෑම රැස් කරති',
#  'අක්කලා උදෑසනින් ම අවදි වෙති',
#  'ළමයි උදෑසනින් ම අවදි වී පාසලට යති',
#  'ඔවුහු නිවැරදි ව අකුරු ලියති',
#  'ඔවුහු නිවැරදි තාලයට සින්දු කියති',
#  'ඔවුහු තරගයෙන් ජයග්\u200dරහණය කරති',
#  'ඔවුහු ලස්සන ගීතයක් ගායනා  කරති',
#  'ඔවුහු ලස්සන ගීතයක් රඟ දක්වති',
#  'ඔවුහු පැරණි කවියක් ගායනා  කරති',
#  'නරි කැළය මැදින් ගමන් කරති',
#  'සිංහයෝ කැළය මැදින් ගමන් කරති',
#  'කොටි කැළය මැදින් ගමන් කරති',
#  'අයියලා උදෑසනින් ම අවදි වී රැකියාවට යති',
#  'මාමලා උදෑසනින් ම අවදි වී රැකියාවට යති',
#  'ක්\u200dරීඩකයෝ ක්\u200dරීඩා පිටියට පැමිණෙති',
#  'යෙහෙළියෝ සෙල්ලම් කිරීමට පිටියට පැමිණෙති',
#  'සීයලා මිදුලේ අඹ පැළ සිටුවති',
#  'ආච්චිලා පෝයට සිල් ගැනීමට පන්සලට යති',
#  'ගස් ඉතා වේගයෙන් සෙලවෙයි',
#  'සරුංගල් අහසේ පාවී පාවී තිබෙයි',
#  'නැව් සයුරේ යාත්\u200dරා කරයි',
#  'තාරකා දීප්තිමත් ව අහසේ බැබළෙයි',
#  'ගස් සුළඟට ඉදිරී වැටෙයි',
#  'ගංගා මුහුදට සීරුවෙන් ගලා බසියි',
#  'මල් පරවී බිම වැටෙයි',
#  'නිවෙස් ජල ගැල්මට හසු වී යට වෙයි',
#  'උදෑසන ම ලස්සන මල් පිපෙයි',
#  'ඉහළ අහසේ සරුංගල් පාවෙයි',
#  'ගල් කන්දෙන් පහළට පෙරලෙයි',
#  'කොළ වේගයෙන් සුළඟට ගසාගෙන යයි',
#  'රාත්\u200dරී අහසේ ලස්සන තරු පායයි',
#  'ගුවන්විදුලි යන්ත්\u200dර ක්\u200dරියාත්මක වෙයි',
#  'රූපවාහිනී යන්ත්\u200dර ක්\u200dරියාත්මක වෙමින් තිබෙයි']

# %%
joined_rows
# Out:
# '\ufeffතාත්තා මිදුලේ සිටියි.තාත්තා එළවළු පාත්තිවලට පොහොර දමයි.අම්මා කුස්සියේ සිටියි.අම්මා රස කෑමක් සාදයි.මල්ලී මිදුලේ සෙල්ලම් කරයි.නංගී මිදුලේ සෙල්ලම් කරයි.සිංහයා ගස යට සිටියි.වෛද්\u200dයතුමා රෝගියාට බෙහෙත් දෙයි.වෛද්\u200dයතුමිය රෝගියාට බෙහෙත් දෙයි.වෛද්\u200dයතුමා රෝගියාට කරුණාවෙන් සවන් දෙයි.වෛද්\u200dයතුමිය රෝගියාට කරුණාවෙන් කතා කරයි.සමනලයා මල් පැණි බොයි.ලේනා ගස් උඩ පැන පැන නටයි.ගායිකාව මිහිරි ගීතයක් ගයයි.ගුරුවරිය පාඩම් කියා දෙයි.අක්කා ශබ්ද නගා පාඩම් කරයි.ගොවියා උදෑසනින් කුඹුරට යයි.කුරුල්ලා අහසේ පියාඹයි.ඔහු ගසට නැග පේර කඩයි.හේ මහ පාර අසලට වී සිටියි.හෙතෙම පයින් ම නගරයට යයි.තාත්තා පොරව ගෙන කොටය පළයි.මාමා උදැල්ල ගෙන වල් කොටයි.ගොනා ළපටි තණකොළ කයි.බල්ලා අහසට උඩු බුරයි.හාවා වේගයෙන් පැන පැන යයි.තාරාවා වැව් ජලයේ වේගයෙන් පීනයි.ගොවියා කෙතට බැස ගොයම් කපයි.ඇය රැකියාව බලා පිටත් වෙයි.බල්ලා වේගයෙන් ද
ා කරයි.ඇය ලස්සන ගීතයක් ගායනා කරයි.ඇය ලස්සන ගීතයක් ගායනා කරන්නීය.නරියා කැළය මැදින් ගමන් කරයි.සිංහයා කැළය මැදින් ගමන් කරයි.කොටියා කැළය මැදින් ගමන් කරයි.අයියා උදෑසනින් ම අවදි වී රැකියාවට යයි.මාමා උදෑසනින් ම අවදි වී රැකියාවට යයි.ක්\u200dරීඩකයා ක්\u200dරීඩා පිටියට පැමිණෙයි.යෙහෙළිය සෙල්ලම් කිරීමට පිටියට පැමිණෙයි.සීයා මිදුලේ අඹ පැළයක් සිටුවයි.ආච්චි පෝයට සිල් ගැනීමට පන්සලට යයි.ගස ඉතා වේගයෙන් සෙලවෙයි.සරුංගලය අහසේ පාවී පාවී තිබෙයි.නැව සයුරේ යාත්\u200dරා කරමින් සිටියි.තාරකාව දීප්තිමත්ව අහසේ බැබළෙයි.ගස සුළඟට ඉදිරී වැටෙයි.ගංගාව මුහුදට සීරුවෙන් ගලා බසියි.මල පරවී බිම වැටෙයි.නිවස ජල ගැල්මට හසු වී යට වෙයි.උදෑසනම ලස්සන මලක් පිපෙයි.ඉහළ අහසේ සරුංගලයක් පාවෙයි.බෝලය කන්දෙන් පහළට පෙරලෙයි.කොළය වේගයෙන් සුළඟට ගසාගෙන යයි.රාත්\u200dරී අහසේ ලස්සන තරුවක් පායයි.ගුවන්විදුලි යන්ත්\u200dරය ක්\u200dරියාත්මක වෙයි.රූපවාහිනී යන්ත්\u200dරය ක්\u200dරියාත්මක වෙමින් තිබෙයි.තාත්තලා මිදුලේ සිටිති.තාත්තලා එළවළු පාත්තිවලට පොහොර දමති.අම්මලා කුස්සියේ සිටිති.අම්මලා රස කෑමක් සාදති.මල්ලිලා මිදුලේ සෙල්ලම් කරති.නංගිලා මිදුලේ සෙල්ලම් කරති.සිංහයෝ ගස යට නිදති.වෛද්\u200dයවරු රෝගියාට බෙහෙත් දෙති.වෛද්\u200dයවරියෝ රෝගියාට බෙහෙත් දෙති.වෛද්\u200dයවරු රෝගීන්ට කරුණාවෙන් සවන් දෙති.වෛද්\u200dයවරියෝ රෝගීන්ට කරුණාවෙන් කතා  කරති.සමනලයෝ මල් පැණි බොති.කුරුල්ලෝ ගස් උඩ පැන පැන නටති.ගායිකාවෝ මිහිරි ගීතයක් ගයති.ගුරුවරු පාඩම් කියා දෙති.අක්කලා ශබ්ද නගා පාඩම් කරති.ගොවියෝ උදෑසනින් කුඹුරට යති.කුරුල්ලෝ අහසේ පියාඹති.ඔවුහු ගසට නැග පේර කඩති.ඔවුහු මහ පාර අසලට වී සිටිති.ඔවුහු පයින් ම නගරයට යති.තාත්තලා කැළයට ගොස් ගස් කපති.මාමලා උදලු ගෙන වල් කොටති.ගවයෝ ළපටි තණකොළ කති.බල්ලෝ අහසට උඩු බුරති.හාවෝ වේගයෙන් පැන පැන යති.තාරාවෝ වැව් ජලයේ වේ ...

# %% [markdown]
# ### For the "Prathama Eka Wachana" Sentence

# %%
input_text = joined_rows
letter_comb = "යි"

# %%
# Convert Sinhala letters to English
english_text = sinhala_to_english(input_text)
print("Input Text in Sinhala:")
print(input_text)
print("\nConverted to English Letters:")
print(english_text)

start_text = sinhala_to_english(letter_comb)
print("\nConverted Starting Letter:")
print(start_text)


def count_correct_grammar_sentences(english_text, start_text):
    # Check grammar using the previous code
    results = check_grammar(english_text, start_text)

    correct_grammar_count = results.count("Correct Grammar")
    incorrect_grammar_count = results.count("Incorrect Grammar")

    return correct_grammar_count, incorrect_grammar_count


# Check grammar using the previous code
results = check_grammar(english_text, start_text)
print("\nGrammar Check Results:")
sentences = english_text.split('.')
for i, sentence in enumerate(sentences):
    print(f"Sentence {i + 1}: {sentence.strip()}")
    print(f"Grammar: {results[i]}\n")

# Example usage:
correct_grammar_count, incorrect_grammar_count = count_correct_grammar_sentences(english_text, start_text)

print(f"Number of Correct Grammar Sentences: {correct_grammar_count}")
print(f"Number of Incorrect Grammar Sentences: {incorrect_grammar_count - 1}")
# Out:
# Input Text in Sinhala:
# ﻿තාත්තා මිදුලේ සිටියි.තාත්තා එළවළු පාත්තිවලට පොහොර දමයි.අම්මා කුස්සියේ සිටියි.අම්මා රස කෑමක් සාදයි.මල්ලී මිදුලේ සෙල්ලම් කරයි.නංගී මිදුලේ සෙල්ලම් කරයි.සිංහයා ගස යට සිටියි.වෛද්‍යතුමා රෝගියාට බෙහෙත් දෙයි.වෛද්‍යතුමිය රෝගියාට බෙහෙත් දෙයි.වෛද්‍යතුමා රෝගියාට කරුණාවෙන් සවන් දෙයි.වෛද්‍යතුමිය රෝගියාට කරුණාවෙන් කතා කරයි.සමනලයා මල් පැණි බොයි.ලේනා ගස් උඩ පැන පැන නටයි.ගායිකාව මිහිරි ගීතයක් ගයයි.ගුරුවරිය පාඩම් කියා දෙයි.අක්කා ශබ්ද නගා පාඩම් කරයි.ගොවියා උදෑසනින් කුඹුරට යයි.කුරුල්ලා අහසේ පියාඹයි.ඔහු ගසට නැග පේර කඩයි.හේ මහ පාර අසලට වී සිටියි.හෙතෙම පයින් ම නගරයට යයි.තාත්තා පොරව ගෙන කොටය පළයි.මාමා උදැල්ල ගෙන වල් කොටයි.ගොනා ළපටි තණකොළ කයි.බල්ලා අහසට උඩු බුරයි.හාවා වේගයෙන් පැන පැන යයි.තාරාවා වැව් ජලයේ වේගයෙන් පීනයි.ගොවියා කෙතට බැස ගොයම් කපයි.ඇය රැකියාව බලා පිටත් වෙයි.බල්ලා වේගයෙන් දුවයි.අම්මා දිවා ආහාර පිසින්නීය.අක්කා තාලයට නටන්නීය.නැන්දා යහපත් වැඩ කරන්නීය.නැන්දා යහපත් වැඩ කරයි.ගෙවිළිය කෙතට බැස ගොයම් කපන්නීය.ගෙවිළිය කෙතට බැස ගොයම් කපයි.අම්මා දිවා ආහාර පිසියි.අක්කා තාලයට නටයි.එළදෙන තණකොළ කන්නීය.එළදෙන තණකොළ කයි.අම්මා රසවත් ආහාර සකසයි.තාත්තා දිනපතා රැකියාවට යයි.
yi.gs ithaa weegyen selweyi.srungly ahsee pawii pawii thaibeyi.naew syuree yatha‍ra krmin sitiyi.thaarkaw diipthaimthaw ahsee baebleyi.gs sulඟt idirii waeteyi.gngaw muhudt siiruwen gla bsiyi.ml prwii bim waeteyi.niws jl gaelmt hsu wii yt weyi.උdaeesnm lssn mlk pipeyi.ihl ahsee srunglyk paweyi.booly knden phlt perleyi.koly weegyen sulඟt gsagen yyi.ratha‍rii ahsee lssn tharuwk payyi.guwnwiduli yntha‍ry k‍riyathamk weyi.ruupwahinii yntha‍ry k‍riyathamk wemin thaibeyi.thaathathala midulee sitithai.thaathathala elwlu pathathaiwlt pohor dmthai.ammla kussiyee sitithai.ammla rs kaeemk sadthai.mllila midulee sellm krthai.nngila midulee sellm krthai.sinhyoo gs yt nidthai.weid‍ywru roogiyat behetha dethai.weid‍ywriyoo roogiyat behetha dethai.weid‍ywru roogiint kruණawen swn dethai.weid‍ywriyoo roogiint kruණawen kthaa  krthai.smnlyoo ml paeණi bothai.kurulloo gs උd paen paen ntthai.gayikawoo mihiri giithayk gythai.guruwru padm kiya dethai.akkla ශbd nga padm krthai.gowiyoo උdaeesnin kuඹurt ythai.kurulloo ahsee piyaඹthai.ඔwuhu gst naeg peer kdthai.ඔwuhu mh par aslt wii sitithai.ඔwuhu pyin m ngryt ythai.thaathathala kael ...
#
# Converted Starting Letter:
# yi
#
# Grammar Check Results:
# Sentence 1: ﻿thaathathaa midulee sitiyi
# Grammar: Correct Grammar
#
# Sentence 2: thaathathaa elwlu pathathaiwlt pohor dmyi
# Grammar: Correct Grammar
#
# Sentence 3: amma kussiyee sitiyi
# Grammar: Correct Grammar
#
# Sentence 4: amma rs kaeemk sadyi
# Grammar: Correct Grammar
#
# Sentence 5: mllii midulee sellm kryi
# Grammar: Correct Grammar
#
# Sentence 6: nngii midulee sellm kryi
# Grammar: Correct Grammar
#
# Sentence 7: sinhya gs yt sitiyi
# Grammar: Correct Grammar
#
# Sentence 8: weid‍ythauma roogiyat behetha deyi
# Grammar: Correct Grammar
#
# Sentence 9: weid‍ythaumiy roogiyat behetha deyi
# Grammar: Correct Grammar
#
# Sentence 10: weid‍ythauma roogiyat kruණawen swn deyi
# Grammar: Correct Grammar
#
# Sentence 11: weid‍ythaumiy roogiyat kruණawen kthaa kryi
# Grammar: Correct Grammar
#
# Sentence 12: smnlya ml paeණi boyi
# Grammar: Correct Grammar
#
# Sentence 13: leena gs උd paen paen ntyi
# Grammar: Correct Grammar
#
# Sentence 14: gayikaw mihiri giithayk gyyi
# Grammar: Correct Grammar
#
# Sentence 15: guruwriy padm kiya deyi
# Grammar: Correct Grammar
#
# Sentence 16: akka ශbd nga padm kryi
# Grammar: Correct Grammar
#
# Sentence 17: gowiya උdaeesnin kuඹurt yyi
# Grammar: Correct Grammar
#
# Sentence 18: kurulla ahsee piyaඹyi
# Grammar: Correct Grammar
#
# Sentence 19: ඔhu gst naeg peer kdyi
# Grammar: Correct Grammar
#
# Sentence 20: hee mh par aslt wii sitiyi
# Grammar: Correct Grammar
#
# Sentence 21: hethaem pyin m ngryt yyi
# Grammar: Correct Grammar
#
# Sentence 22: thaathathaa porw gen koty plyi
# Grammar: Correct Grammar
#
# Sentence 23: mama උdaell gen wl kotyi
# Grammar: Correct Grammar
#
# Sentence 24: gona lpti thaණkol kyi
# Grammar: Correct Grammar
#
# Sentence 25: blla ahst උdu buryi
# Grammar: Correct Grammar
#
# Sentence 26: hawa weegyen paen paen yyi
# Grammar: Correct Grammar
#
# Sentence 27: thaarawa waew jlyee weegyen piinyi
# Grammar: Correct Grammar
#
# Sentence 28: gowiya kethat baes goym kpyi
# Grammar: Correct Grammar
#
# Sentence 29: ඇy raekiyaw bla pittha weyi
# Grammar: Correct Grammar
#
# Sentence 30: blla weegyen duwyi
# Grammar: Correct Grammar
#
# Sentence 31: amma diwa aahar pisinniiy
# Grammar: Incorrect Grammar
#
# Sentence 32: akka thaalyt ntnniiy
# Grammar: Incorrect Grammar
#
# Sentence 33: naenda yhptha waed krnniiy
# Grammar: Incorrect Grammar
#
# Sentence 34: naenda yhptha waed kryi
# Grammar: Correct Grammar
#
# Sentence 35: gewiliy kethat baes goym kpnniiy
# Grammar: Incorrect Grammar
#
# Sentence 36: gewiliy kethat baes goym kpyi
# Grammar: Correct Grammar
#
# Sentence 37: amma diwa aahar pisiyi
# Grammar: Correct Grammar
#
# Sentence 38: akka thaalyt ntyi
# Grammar: Correct Grammar
#
# Sentence 39: elden thaණkol knniiy
# Grammar: Incorrect Grammar
#
# Sentence 40: elden thaණkol kyi
# Grammar: Correct Grammar
#
# Sentence 41: amma rswtha aahar sksyi
# Grammar: Correct Grammar
#
# Sentence 42: thaathathaa dinpthaa raekiyawt yyi
# Grammar: Correct Grammar
#
# Sentence 43: akka lssn gwumk msmin sitiyi
# Grammar: Correct Grammar
#
# Sentence 44: kurulla aඹ gs muduණee sitiyi
# Grammar: Correct Grammar
#
# Sentence 45: puusa midul pura duwmin sellm kryi
# Grammar: Correct Grammar
#
# Sentence 46: mllii midul pura duwmin sellm kryi
# Grammar: Correct Grammar
#
# Sentence 47: nngii midul pura duwmin sellm kryi
# Grammar: Correct Grammar
#
# Sentence 48: blla midul pura duwmin sellm kryi
# Grammar: Correct Grammar
#
# Sentence 49: guruthauma gණithay padm උgnwyi
# Grammar: Correct Grammar
#
# Sentence 50: widuhlpthaithauma paslt weelasnin paemiණeyi
# Grammar: Correct Grammar
#
# Sentence 51: widuhlpthaithaumiy paslt weelasnin paemiණeyi
# Grammar: Correct Grammar
#
# Sentence 52: kurulla gs muduණee kuuduwk thanyi
# Grammar: Correct Grammar
#
# Sentence 53: gaykya mihiri giithayk gayna kryi
# Grammar: Correct Grammar
#
# Sentence 54: guruwrya lmyint padm kiya deyi
# Grammar: Correct Grammar
#
# Sentence 55: ayiya ශbd nga padm kryi
# Grammar: Correct Grammar
#
# Sentence 56: gewiliy උdaeesnin kuඹurt yyi
# Grammar: Correct Grammar
#
# Sentence 57: උkussa ahsee piya sryi
# Grammar: Correct Grammar
#
# Sentence 58: ඇy gst naeg peer kdyi
# Grammar: Correct Grammar
#
# Sentence 59: hee pnsl aslt wii sitiyi
# Grammar: Correct Grammar
#
# Sentence 60: hethaem pyin m niws bla yyi
# Grammar: Correct Grammar
#
# Sentence 61: amma porw gen koty plyi
# Grammar: Correct Grammar
#
# Sentence 62: ayiya උdaell gen wl kotyi
# Grammar: Correct Grammar
#
# Sentence 63: gwya lpti thaණkol kyi
# Grammar: Correct Grammar
#
# Sentence 64: blla weegyen duwmin sellm kryi
# Grammar: Correct Grammar
#
# Sentence 65: kaengruwa weegyen paen paen yyi
# Grammar: Correct Grammar
#
# Sentence 66: mllii waew jlyee weegyen piinyi
# Grammar: Correct Grammar
#
# Sentence 67: gewiliy kethat baes goym kpyi
# Grammar: Correct Grammar
#
# Sentence 68: ඔhu raekiyaw bla pittha weyi
# Grammar: Correct Grammar
#
# Sentence 69: mllii weegyen wthauree piinyi
# Grammar: Correct Grammar
#
# Sentence 70: akka diwa aahar pisinniiy
# Grammar: Incorrect Grammar
#
# Sentence 71: akka giithaykt lssnt ntnniiy
# Grammar: Incorrect Grammar
#
# Sentence 72: naenda yhptha waed kiya denniiy
# Grammar: Incorrect Grammar
#
# Sentence 73: naenda yhptha waed kiya deyi
# Grammar: Correct Grammar
#
# Sentence 74: gowiya kethat baes goym kpyi
# Grammar: Correct Grammar
#
# Sentence 75: gewiliy kethat baes goym sitwyi
# Grammar: Correct Grammar
#
# Sentence 76: akka giithaykt lssnt ntyi
# Grammar: Correct Grammar
#
# Sentence 77: akka thaalyt athapudi gsyi
# Grammar: Correct Grammar
#
# Sentence 78: mgiya bsyt naeg sit gniyi
# Grammar: Correct Grammar
#
# Sentence 79: thaotiya ඔruw diytha krmin sitiyi
# Grammar: Correct Grammar
#
# Sentence 80: palkya rt palny kryi
# Grammar: Correct Grammar
#
# Sentence 81: muwa kaely maedin gmn kryi
# Grammar: Correct Grammar
#
# Sentence 82: aliya waewen diy boyi
# Grammar: Correct Grammar
#
# Sentence 83: kuuඹiya ශiitha kalyt kaeem raes kryi
# Grammar: Correct Grammar
#
# Sentence 84: akka උdaeesnin m awdi weyi
# Grammar: Correct Grammar
#
# Sentence 85: lmya උdaeesnin m awdi wii paslt yyi
# Grammar: Correct Grammar
#
# Sentence 86: ඔhu niwaerdi w akuru liyyi
# Grammar: Correct Grammar
#
# Sentence 87: ඇy niwaerdi w akuru liyyi
# Grammar: Correct Grammar
#
# Sentence 88: ඇy niwaerdi w akuru liynniiy
# Grammar: Incorrect Grammar
#
# Sentence 89: ඔhu lssn giithayk gayna kryi
# Grammar: Correct Grammar
#
# Sentence 90: ඇy lssn giithayk gayna kryi
# Grammar: Correct Grammar
#
# Sentence 91: ඇy lssn giithayk gayna krnniiy
# Grammar: Incorrect Grammar
#
# Sentence 92: nriya kaely maedin gmn kryi
# Grammar: Correct Grammar
#
# Sentence 93: sinhya kaely maedin gmn kryi
# Grammar: Correct Grammar
#
# Sentence 94: kotiya kaely maedin gmn kryi
# Grammar: Correct Grammar
#
# Sentence 95: ayiya උdaeesnin m awdi wii raekiyawt yyi
# Grammar: Correct Grammar
#
# Sentence 96: mama උdaeesnin m awdi wii raekiyawt yyi
# Grammar: Correct Grammar
#
# Sentence 97: k‍riidkya k‍riida pitiyt paemiණeyi
# Grammar: Correct Grammar
#
# Sentence 98: yeheliy sellm kiriimt pitiyt paemiණeyi
# Grammar: Correct Grammar
#
# Sentence 99: siiya midulee aඹ paelyk situwyi
# Grammar: Correct Grammar
#
# Sentence 100: aacci pooyt sil gaeniimt pnslt yyi
# Grammar: Correct Grammar
#
# Sentence 101: gs ithaa weegyen selweyi
# Grammar: Correct Grammar
#
# Sentence 102: srungly ahsee pawii pawii thaibeyi
# Grammar: Correct Grammar
#
# Sentence 103: naew syuree yatha‍ra krmin sitiyi
# Grammar: Correct Grammar
#
# Sentence 104: thaarkaw diipthaimthaw ahsee baebleyi
# Grammar: Correct Grammar
#
# Sentence 105: gs sulඟt idirii waeteyi
# Grammar: Correct Grammar
#
# Sentence 106: gngaw muhudt siiruwen gla bsiyi
# Grammar: Correct Grammar
#
# Sentence 107: ml prwii bim waeteyi
# Grammar: Correct Grammar
#
# Sentence 108: niws jl gaelmt hsu wii yt weyi
# Grammar: Correct Grammar
#
# Sentence 109: උdaeesnm lssn mlk pipeyi
# Grammar: Correct Grammar
#
# Sentence 110: ihl ahsee srunglyk paweyi
# Grammar: Correct Grammar
#
# Sentence 111: booly knden phlt perleyi
# Grammar: Correct Grammar
#
# Sentence 112: koly weegyen sulඟt gsagen yyi
# Grammar: Correct Grammar
#
# Sentence 113: ratha‍rii ahsee lssn tharuwk payyi
# Grammar: Correct Grammar
#
# Sentence 114: guwnwiduli yntha‍ry k‍riyathamk weyi
# Grammar: Correct Grammar
#
# Sentence 115: ruupwahinii yntha‍ry k‍riyathamk wemin thaibeyi
# Grammar: Correct Grammar
#
# Sentence 116: thaathathala midulee sitithai
# Grammar: Incorrect Grammar
#
# Sentence 117: thaathathala elwlu pathathaiwlt pohor dmthai
# Grammar: Incorrect Grammar
#
# Sentence 118: ammla kussiyee sitithai
# Grammar: Incorrect Grammar
#
# Sentence 119: ammla rs kaeemk sadthai
# Grammar: Incorrect Grammar
#
# Sentence 120: mllila midulee sellm krthai
# Grammar: Incorrect Grammar
#
# Sentence 121: nngila midulee sellm krthai
# Grammar: Incorrect Grammar
#
# Sentence 122: sinhyoo gs yt nidthai
# Grammar: Incorrect Grammar
#
# Sentence 123: weid‍ywru roogiyat behetha dethai
# Grammar: Incorrect Grammar
#
# Sentence 124: weid‍ywriyoo roogiyat behetha dethai
# Grammar: Incorrect Grammar
#
# Sentence 125: weid‍ywru roogiint kruණawen swn dethai
# Grammar: Incorrect Grammar
#
# Sentence 126: weid‍ywriyoo roogiint kruණawen kthaa  krthai
# Grammar: Incorrect Grammar
#
# Sentence 127: smnlyoo ml paeණi bothai
# Grammar: Incorrect Grammar
#
# Sentence 128: kurulloo gs උd paen paen ntthai
# Grammar: Incorrect Grammar
#
# Sentence 129: gayikawoo mihiri giithayk gythai
# Grammar: Incorrect Grammar
#
# Sentence 130: guruwru padm kiya dethai
# Grammar: Incorrect Grammar
#
# Sentence 131: akkla ශbd nga padm krthai
# Grammar: Incorrect Grammar
#
# Sentence 132: gowiyoo උdaeesnin kuඹurt ythai
# Grammar: Incorrect Grammar
#
# Sentence 133: kurulloo ahsee piyaඹthai
# Grammar: Incorrect Grammar
#
# Sentence 134: ඔwuhu gst naeg peer kdthai
# Grammar: Incorrect Grammar
#
# Sentence 135: ඔwuhu mh par aslt wii sitithai
# Grammar: Incorrect Grammar
#
# Sentence 136: ඔwuhu pyin m ngryt ythai
# Grammar: Incorrect Grammar
#
# Sentence 137: thaathathala kaelyt gos gs kpthai
# Grammar: Incorrect Grammar
#
# Sentence 138: mamla උdlu gen wl kotthai
# Grammar: Incorrect Grammar
#
# Sentence 139: gwyoo lpti thaණkol kthai
# Grammar: Incorrect Grammar
#
# Sentence 140: blloo ahst උdu burthai
# Grammar: Incorrect Grammar
#
# Sentence 141: hawoo weegyen paen paen ythai
# Grammar: Incorrect Grammar
#
# Sentence 142: thaarawoo waew jlyee weegyen piinthai
# Grammar: Incorrect Grammar
#
# Sentence 143: gowiyoo kethat baes goym kpthai
# Grammar: Incorrect Grammar
#
# Sentence 144: ඔwuhu raekiyawn bla pittha wethai
# Grammar: Incorrect Grammar
#
# Sentence 145: blloo weegyen paree duwthai
# Grammar: Incorrect Grammar
#
# Sentence 146: ammla wehes wii diwa aahar pisithai
# Grammar: Incorrect Grammar
#
# Sentence 147: akkla thaalyt pad thabmin ntthai
# Grammar: Incorrect Grammar
#
# Sentence 148: naendla yhptha waed krthai
# Grammar: Incorrect Grammar
#
# Sentence 149: naendla redi soo dmin sitithai
# Grammar: Incorrect Grammar
#
# Sentence 150: gewiliyoo kethat baes goym kpthai
# Grammar: Incorrect Grammar
#
# Sentence 151: gewiliyoo kethat baes goym situwthai
# Grammar: Incorrect Grammar
#
# Sentence 152: ammla rswtha aahar pisithai
# Grammar: Incorrect Grammar
#
# Sentence 153: akkla thaalyt giitha kiythai
# Grammar: Incorrect Grammar
#
# Sentence 154: eldennu pittniyee thaණkol kthai
# Grammar: Incorrect Grammar
#
# Sentence 155: eldennu pittniyee thaණkol kmin sitithai
# Grammar: Incorrect Grammar
#
# Sentence 156: ammla rswtha aahar sksmin sitithai
# Grammar: Incorrect Grammar
#
# Sentence 157: thaathathala dinpthaa raekiyawt ythai
# Grammar: Incorrect Grammar
#
# Sentence 158: akkla lssn gwum msmin sitithai
# Grammar: Incorrect Grammar
#
# Sentence 159: kurulloo aඹ gs muduණee sitithai
# Grammar: Incorrect Grammar
#
# Sentence 160: puusoo midul pura duwmin sellm krthai
# Grammar: Incorrect Grammar
#
# Sentence 161: mllila midul pura duwmin sellm krthai
# Grammar: Incorrect Grammar
#
# Sentence 162: nngila midul pura duwmin sellm krthai
# Grammar: Incorrect Grammar
#
# Sentence 163: blloo midul pura duwmin sellm krthai
# Grammar: Incorrect Grammar
#
# Sentence 164: guruwru gණithay padm niwaerdiw උgnwthai
# Grammar: Incorrect Grammar
#
# Sentence 165: guruwru paslt weelasnin paemiණethai
# Grammar: Incorrect Grammar
#
# Sentence 166: widuhlpthaiwru paslt weelasnin paemiණethai
# Grammar: Incorrect Grammar
#
# Sentence 167: kurulloo gs muduණee kuuduwk thanthai
# Grammar: Incorrect Grammar
#
# Sentence 168: gaykyoo mihiri giithayk gayna  krthai
# Grammar: Incorrect Grammar
#
# Sentence 169: guruwru lmyint padm kiya dethai
# Grammar: Incorrect Grammar
#
# Sentence 170: ayiyla ශbd nga padm krthai
# Grammar: Incorrect Grammar
#
# Sentence 171: gewiliyoo උdaeesnin kuඹurt ythai
# Grammar: Incorrect Grammar
#
# Sentence 172: උkussoo ahsee piyasrthai
# Grammar: Incorrect Grammar
#
# Sentence 173: ඔwuhu gst naeg aඹ kdthai
# Grammar: Incorrect Grammar
#
# Sentence 174: ඔwuhu pasl aslt wii sitithai
# Grammar: Incorrect Grammar
#
# Sentence 175: ඔwuhu pyin m pnsl bla ythai
# Grammar: Incorrect Grammar
#
# Sentence 176: ammla උdlu gen polow kotthai
# Grammar: Incorrect Grammar
#
# Sentence 177: ayiyla උdlu gen wl kotthai
# Grammar: Incorrect Grammar
#
# Sentence 178: gwyoo lpti thaණkol kthai
# Grammar: Incorrect Grammar
#
# Sentence 179: blloo weegyen duwmin sellm krthai
# Grammar: Incorrect Grammar
#
# Sentence 180: kaengruwoo weegyen paen paen ythai
# Grammar: Incorrect Grammar
#
# Sentence 181: mllila waew jlyee weegyen piinthai
# Grammar: Incorrect Grammar
#
# Sentence 182: gowiyoo kethat baes goym situwthai
# Grammar: Incorrect Grammar
#
# Sentence 183: ඔwuhu rajkarii bla pittha wethai
# Grammar: Incorrect Grammar
#
# Sentence 184: mllila weegyen wthauree piinthai
# Grammar: Incorrect Grammar
#
# Sentence 185: akkla diwa aahar pisithai
# Grammar: Incorrect Grammar
#
# Sentence 186: akkla giithaykt lssnt ntthai
# Grammar: Incorrect Grammar
#
# Sentence 187: naendla yhptha waed kiya dethai
# Grammar: Incorrect Grammar
#
# Sentence 188: naendla yhptha waedwlt yomu krthai
# Grammar: Incorrect Grammar
#
# Sentence 189: gowiyoo kethat baes wii isithai
# Grammar: Incorrect Grammar
#
# Sentence 190: gewiliyoo kethat baes goym pagthai
# Grammar: Incorrect Grammar
#
# Sentence 191: akkla giithaykt lssnt nrthanyee yedethai
# Grammar: Incorrect Grammar
#
# Sentence 192: akkla thaalyt athapudi gsthai
# Grammar: Incorrect Grammar
#
# Sentence 193: mgiyoo bsyt naeg sit gnithai
# Grammar: Incorrect Grammar
#
# Sentence 194: thaotiyoo ඔruw diytha krmin sitithai
# Grammar: Incorrect Grammar
#
# Sentence 195: palkyoo rt palny krthai
# Grammar: Incorrect Grammar
#
# Sentence 196: sthathau kaely maedin gmn krthai
# Grammar: Incorrect Grammar
#
# Sentence 197: ali waewen diy bothai
# Grammar: Incorrect Grammar
#
# Sentence 198: kuuඹi ශiitha kalyt kaeem raes krthai
# Grammar: Incorrect Grammar
#
# Sentence 199: akkla උdaeesnin m awdi wethai
# Grammar: Incorrect Grammar
#
# Sentence 200: lmyi උdaeesnin m awdi wii paslt ythai
# Grammar: Incorrect Grammar
#
# Sentence 201: ඔwuhu niwaerdi w akuru liythai
# Grammar: Incorrect Grammar
#
# Sentence 202: ඔwuhu niwaerdi thaalyt sindu kiythai
# Grammar: Incorrect Grammar
#
# Sentence 203: ඔwuhu thargyen jyg‍rhණy krthai
# Grammar: Incorrect Grammar
#
# Sentence 204: ඔwuhu lssn giithayk gayna  krthai
# Grammar: Incorrect Grammar
#
# Sentence 205: ඔwuhu lssn giithayk rඟ dkwthai
# Grammar: Incorrect Grammar
#
# Sentence 206: ඔwuhu paerණi kwiyk gayna  krthai
# Grammar: Incorrect Grammar
#
# Sentence 207: nri kaely maedin gmn krthai
# Grammar: Incorrect Grammar
#
# Sentence 208: sinhyoo kaely maedin gmn krthai
# Grammar: Incorrect Grammar
#
# Sentence 209: koti kaely maedin gmn krthai
# Grammar: Incorrect Grammar
#
# Sentence 210: ayiyla උdaeesnin m awdi wii raekiyawt ythai
# Grammar: Incorrect Grammar
#
# Sentence 211: mamla උdaeesnin m awdi wii raekiyawt ythai
# Grammar: Incorrect Grammar
#
# Sentence 212: k‍riidkyoo k‍riida pitiyt paemiණethai
# Grammar: Incorrect Grammar
#
# Sentence 213: yeheliyoo sellm kiriimt pitiyt paemiණethai
# Grammar: Incorrect Grammar
#
# Sentence 214: siiyla midulee aඹ pael situwthai
# Grammar: Incorrect Grammar
#
# Sentence 215: aaccila pooyt sil gaeniimt pnslt ythai
# Grammar: Incorrect Grammar
#
# Sentence 216: gs ithaa weegyen selweyi
# Grammar: Correct Grammar
#
# Sentence 217: srungl ahsee pawii pawii thaibeyi
# Grammar: Correct Grammar
#
# Sentence 218: naew syuree yatha‍ra kryi
# Grammar: Correct Grammar
#
# Sentence 219: thaarka diipthaimtha w ahsee baebleyi
# Grammar: Correct Grammar
#
# Sentence 220: gs sulඟt idirii waeteyi
# Grammar: Correct Grammar
#
# Sentence 221: gnga muhudt siiruwen gla bsiyi
# Grammar: Correct Grammar
#
# Sentence 222: ml prwii bim waeteyi
# Grammar: Correct Grammar
#
# Sentence 223: niwes jl gaelmt hsu wii yt weyi
# Grammar: Correct Grammar
#
# Sentence 224: උdaeesn m lssn ml pipeyi
# Grammar: Correct Grammar
#
# Sentence 225: ihl ahsee srungl paweyi
# Grammar: Correct Grammar
#
# Sentence 226: gl knden phlt perleyi
# Grammar: Correct Grammar
#
# Sentence 227: kol weegyen sulඟt gsagen yyi
# Grammar: Correct Grammar
#
# Sentence 228: ratha‍rii ahsee lssn tharu payyi
# Grammar: Correct Grammar
#
# Sentence 229: guwnwiduli yntha‍r k‍riyathamk weyi
# Grammar: Correct Grammar
#
# Sentence 230: ruupwahinii yntha‍r k‍riyathamk wemin thaibeyi
# Grammar: Correct Grammar
#
# Number of Correct Grammar Sentences: 120
# Number of Incorrect Grammar Sentences: 109

# %% [markdown]
# ## For "Prathama Bahuwachana" Sentence

# %%
input_text = joined_rows
letter_comb = "ති"

# %%
def check_grammarPratha(text, letter_combination):
    # Split the text into sentences
    sentences = re.split(r'[.?]', text)

    # print(sentences)

    results = []

    for sentence in sentences:
        # Split each sentence into words
        words = sentence.split()

        # Check if there are at least two words in the sentence
        if len(words) >= 1:
            last_word = words[-1].strip(".,!?")

            # Check if the last two letters of the last word match the specified letter combination
            if last_word[-4:].lower() == letter_combination.lower():
                results.append("Correct Grammar")
            else:
                results.append("Incorrect Grammar")
        else:
            # If there are no words in the sentence, it's considered incorrect grammar
            results.append("Incorrect Grammar")

    return results

# %%
# Convert Sinhala letters to English
english_text = sinhala_to_english(input_text)
print("Input Text in Sinhala:")
print(input_text)
print("\nConverted to English Letters:")
print(english_text)

start_text = sinhala_to_english(letter_comb)
print("\nConverted Starting Letter:")
print(start_text)


def count_correct_grammar_sentences(english_text, start_text):
    # Check grammar using the previous code
    results = check_grammarPratha(english_text, start_text)

    correct_grammar_count = results.count("Correct Grammar")
    incorrect_grammar_count = results.count("Incorrect Grammar")

    return correct_grammar_count, incorrect_grammar_count


# Check grammar using the previous code
results = check_grammarPratha(english_text, start_text)
print("\nGrammar Check Results:")
sentences = english_text.split('.')
for i, sentence in enumerate(sentences):
    print(f"Sentence {i + 1}: {sentence.strip()}")
    print(f"Grammar: {results[i]}\n")

# Example usage:
correct_grammar_count, incorrect_grammar_count = count_correct_grammar_sentences(english_text, start_text)

print(f"Number of Correct Grammar Sentences: {correct_grammar_count}")
print(f"Number of Incorrect Grammar Sentences: {incorrect_grammar_count - 1}")
# Out:
# Input Text in Sinhala:
# ﻿තාත්තා මිදුලේ සිටියි.තාත්තා එළවළු පාත්තිවලට පොහොර දමයි.අම්මා කුස්සියේ සිටියි.අම්මා රස කෑමක් සාදයි.මල්ලී මිදුලේ සෙල්ලම් කරයි.නංගී මිදුලේ සෙල්ලම් කරයි.සිංහයා ගස යට සිටියි.වෛද්‍යතුමා රෝගියාට බෙහෙත් දෙයි.වෛද්‍යතුමිය රෝගියාට බෙහෙත් දෙයි.වෛද්‍යතුමා රෝගියාට කරුණාවෙන් සවන් දෙයි.වෛද්‍යතුමිය රෝගියාට කරුණාවෙන් කතා කරයි.සමනලයා මල් පැණි බොයි.ලේනා ගස් උඩ පැන පැන නටයි.ගායිකාව මිහිරි ගීතයක් ගයයි.ගුරුවරිය පාඩම් කියා දෙයි.අක්කා ශබ්ද නගා පාඩම් කරයි.ගොවියා උදෑසනින් කුඹුරට යයි.කුරුල්ලා අහසේ පියාඹයි.ඔහු ගසට නැග පේර කඩයි.හේ මහ පාර අසලට වී සිටියි.හෙතෙම පයින් ම නගරයට යයි.තාත්තා පොරව ගෙන කොටය පළයි.මාමා උදැල්ල ගෙන වල් කොටයි.ගොනා ළපටි තණකොළ කයි.බල්ලා අහසට උඩු බුරයි.හාවා වේගයෙන් පැන පැන යයි.තාරාවා වැව් ජලයේ වේගයෙන් පීනයි.ගොවියා කෙතට බැස ගොයම් කපයි.ඇය රැකියාව බලා පිටත් වෙයි.බල්ලා වේගයෙන් දුවයි.අම්මා දි
iy.ඔhu lssn giithayk gayna kryi.ඇy lssn giithayk gayna kryi.ඇy lssn giithayk gayna krnniiy.nriya kaely maedin gmn kryi.sinhya kaely maedin gmn kryi.kotiya kaely maedin gmn kryi.ayiya උdaeesnin m awdi wii raekiyawt yyi.mama උdaeesnin m awdi wii raekiyawt yyi.k‍riidkya k‍riida pitiyt paemiණeyi.yeheliy sellm kiriimt pitiyt paemiණeyi.siiya midulee aඹ paelyk situwyi.aacci pooyt sil gaeniimt pnslt yyi.gs ithaa weegyen selweyi.srungly ahsee pawii pawii thaibeyi.naew syuree yatha‍ra krmin sitiyi.thaarkaw diipthaimthaw ahsee baebleyi.gs sulඟt idirii waeteyi.gngaw muhudt siiruwen gla bsiyi.ml prwii bim waeteyi.niws jl gaelmt hsu wii yt weyi.උdaeesnm lssn mlk pipeyi.ihl ahsee srunglyk paweyi.booly knden phlt perleyi.koly weegyen sulඟt gsagen yyi.ratha‍rii ahsee lssn tharuwk payyi.guwnwiduli yntha‍ry k‍riyathamk weyi.ruupwahinii yntha‍ry k‍riyathamk wemin thaibeyi.thaathathala midulee sitithai.thaathathala elwlu pathathaiwlt pohor dmthai.ammla kussiyee sitithai.ammla rs kaeemk sadthai.mllila midulee sellm krthai.nngila midulee sellm krthai.sinhyoo gs yt nidthai.weid‍ywru roogiyat behetha dethai.weid‍ywriyoo roogiyat behetha dethai.weid‍ywru roogiint kruණawen swn dethai.weid‍ywriyoo roogiint kruණawen kthaa  krthai.smnlyoo ml paeණi bothai.kurulloo gs උd paen paen ntthai.gayikawoo mihiri giithayk gythai.guruwru padm kiya dethai.akkla ශbd nga padm krthai.gowiyoo උdaeesnin kuඹurt ythai.kurulloo ahsee piyaඹthai.ඔwuhu gst naeg peer kdthai.ඔwuhu mh par aslt wii sitithai.ඔwuhu pyin m ngryt ythai.thaathathala kael ...
#
# Converted Starting Letter:
# thai
#
# Grammar Check Results:
# Sentence 1: ﻿thaathathaa midulee sitiyi
# Grammar: Incorrect Grammar
#
# Sentence 2: thaathathaa elwlu pathathaiwlt pohor dmyi
# Grammar: Incorrect Grammar
#
# Sentence 3: amma kussiyee sitiyi
# Grammar: Incorrect Grammar
#
# Sentence 4: amma rs kaeemk sadyi
# Grammar: Incorrect Grammar
#
# Sentence 5: mllii midulee sellm kryi
# Grammar: Incorrect Grammar
#
# Sentence 6: nngii midulee sellm kryi
# Grammar: Incorrect Grammar
#
# Sentence 7: sinhya gs yt sitiyi
# Grammar: Incorrect Grammar
#
# Sentence 8: weid‍ythauma roogiyat behetha deyi
# Grammar: Incorrect Grammar
#
# Sentence 9: weid‍ythaumiy roogiyat behetha deyi
# Grammar: Incorrect Grammar
#
# Sentence 10: weid‍ythauma roogiyat kruණawen swn deyi
# Grammar: Incorrect Grammar
#
# Sentence 11: weid‍ythaumiy roogiyat kruණawen kthaa kryi
# Grammar: Incorrect Grammar
#
# Sentence 12: smnlya ml paeණi boyi
# Grammar: Incorrect Grammar
#
# Sentence 13: leena gs උd paen paen ntyi
# Grammar: Incorrect Grammar
#
# Sentence 14: gayikaw mihiri giithayk gyyi
# Grammar: Incorrect Grammar
#
# Sentence 15: guruwriy padm kiya deyi
# Grammar: Incorrect Grammar
#
# Sentence 16: akka ශbd nga padm kryi
# Grammar: Incorrect Grammar
#
# Sentence 17: gowiya උdaeesnin kuඹurt yyi
# Grammar: Incorrect Grammar
#
# Sentence 18: kurulla ahsee piyaඹyi
# Grammar: Incorrect Grammar
#
# Sentence 19: ඔhu gst naeg peer kdyi
# Grammar: Incorrect Grammar
#
# Sentence 20: hee mh par aslt wii sitiyi
# Grammar: Incorrect Grammar
#
# Sentence 21: hethaem pyin m ngryt yyi
# Grammar: Incorrect Grammar
#
# Sentence 22: thaathathaa porw gen koty plyi
# Grammar: Incorrect Grammar
#
# Sentence 23: mama උdaell gen wl kotyi
# Grammar: Incorrect Grammar
#
# Sentence 24: gona lpti thaණkol kyi
# Grammar: Incorrect Grammar
#
# Sentence 25: blla ahst උdu buryi
# Grammar: Incorrect Grammar
#
# Sentence 26: hawa weegyen paen paen yyi
# Grammar: Incorrect Grammar
#
# Sentence 27: thaarawa waew jlyee weegyen piinyi
# Grammar: Incorrect Grammar
#
# Sentence 28: gowiya kethat baes goym kpyi
# Grammar: Incorrect Grammar
#
# Sentence 29: ඇy raekiyaw bla pittha weyi
# Grammar: Incorrect Grammar
#
# Sentence 30: blla weegyen duwyi
# Grammar: Incorrect Grammar
#
# Sentence 31: amma diwa aahar pisinniiy
# Grammar: Incorrect Grammar
#
# Sentence 32: akka thaalyt ntnniiy
# Grammar: Incorrect Grammar
#
# Sentence 33: naenda yhptha waed krnniiy
# Grammar: Incorrect Grammar
#
# Sentence 34: naenda yhptha waed kryi
# Grammar: Incorrect Grammar
#
# Sentence 35: gewiliy kethat baes goym kpnniiy
# Grammar: Incorrect Grammar
#
# Sentence 36: gewiliy kethat baes goym kpyi
# Grammar: Incorrect Grammar
#
# Sentence 37: amma diwa aahar pisiyi
# Grammar: Incorrect Grammar
#
# Sentence 38: akka thaalyt ntyi
# Grammar: Incorrect Grammar
#
# Sentence 39: elden thaණkol knniiy
# Grammar: Incorrect Grammar
#
# Sentence 40: elden thaණkol kyi
# Grammar: Incorrect Grammar
#
# Sentence 41: amma rswtha aahar sksyi
# Grammar: Incorrect Grammar
#
# Sentence 42: thaathathaa dinpthaa raekiyawt yyi
# Grammar: Incorrect Grammar
#
# Sentence 43: akka lssn gwumk msmin sitiyi
# Grammar: Incorrect Grammar
#
# Sentence 44: kurulla aඹ gs muduණee sitiyi
# Grammar: Incorrect Grammar
#
# Sentence 45: puusa midul pura duwmin sellm kryi
# Grammar: Incorrect Grammar
#
# Sentence 46: mllii midul pura duwmin sellm kryi
# Grammar: Incorrect Grammar
#
# Sentence 47: nngii midul pura duwmin sellm kryi
# Grammar: Incorrect Grammar
#
# Sentence 48: blla midul pura duwmin sellm kryi
# Grammar: Incorrect Grammar
#
# Sentence 49: guruthauma gණithay padm උgnwyi
# Grammar: Incorrect Grammar
#
# Sentence 50: widuhlpthaithauma paslt weelasnin paemiණeyi
# Grammar: Incorrect Grammar
#
# Sentence 51: widuhlpthaithaumiy paslt weelasnin paemiණeyi
# Grammar: Incorrect Grammar
#
# Sentence 52: kurulla gs muduණee kuuduwk thanyi
# Grammar: Incorrect Grammar
#
# Sentence 53: gaykya mihiri giithayk gayna kryi
# Grammar: Incorrect Grammar
#
# Sentence 54: guruwrya lmyint padm kiya deyi
# Grammar: Incorrect Grammar
#
# Sentence 55: ayiya ශbd nga padm kryi
# Grammar: Incorrect Grammar
#
# Sentence 56: gewiliy උdaeesnin kuඹurt yyi
# Grammar: Incorrect Grammar
#
# Sentence 57: උkussa ahsee piya sryi
# Grammar: Incorrect Grammar
#
# Sentence 58: ඇy gst naeg peer kdyi
# Grammar: Incorrect Grammar
#
# Sentence 59: hee pnsl aslt wii sitiyi
# Grammar: Incorrect Grammar
#
# Sentence 60: hethaem pyin m niws bla yyi
# Grammar: Incorrect Grammar
#
# Sentence 61: amma porw gen koty plyi
# Grammar: Incorrect Grammar
#
# Sentence 62: ayiya උdaell gen wl kotyi
# Grammar: Incorrect Grammar
#
# Sentence 63: gwya lpti thaණkol kyi
# Grammar: Incorrect Grammar
#
# Sentence 64: blla weegyen duwmin sellm kryi
# Grammar: Incorrect Grammar
#
# Sentence 65: kaengruwa weegyen paen paen yyi
# Grammar: Incorrect Grammar
#
# Sentence 66: mllii waew jlyee weegyen piinyi
# Grammar: Incorrect Grammar
#
# Sentence 67: gewiliy kethat baes goym kpyi
# Grammar: Incorrect Grammar
#
# Sentence 68: ඔhu raekiyaw bla pittha weyi
# Grammar: Incorrect Grammar
#
# Sentence 69: mllii weegyen wthauree piinyi
# Grammar: Incorrect Grammar
#
# Sentence 70: akka diwa aahar pisinniiy
# Grammar: Incorrect Grammar
#
# Sentence 71: akka giithaykt lssnt ntnniiy
# Grammar: Incorrect Grammar
#
# Sentence 72: naenda yhptha waed kiya denniiy
# Grammar: Incorrect Grammar
#
# Sentence 73: naenda yhptha waed kiya deyi
# Grammar: Incorrect Grammar
#
# Sentence 74: gowiya kethat baes goym kpyi
# Grammar: Incorrect Grammar
#
# Sentence 75: gewiliy kethat baes goym sitwyi
# Grammar: Incorrect Grammar
#
# Sentence 76: akka giithaykt lssnt ntyi
# Grammar: Incorrect Grammar
#
# Sentence 77: akka thaalyt athapudi gsyi
# Grammar: Incorrect Grammar
#
# Sentence 78: mgiya bsyt naeg sit gniyi
# Grammar: Incorrect Grammar
#
# Sentence 79: thaotiya ඔruw diytha krmin sitiyi
# Grammar: Incorrect Grammar
#
# Sentence 80: palkya rt palny kryi
# Grammar: Incorrect Grammar
#
# Sentence 81: muwa kaely maedin gmn kryi
# Grammar: Incorrect Grammar
#
# Sentence 82: aliya waewen diy boyi
# Grammar: Incorrect Grammar
#
# Sentence 83: kuuඹiya ශiitha kalyt kaeem raes kryi
# Grammar: Incorrect Grammar
#
# Sentence 84: akka උdaeesnin m awdi weyi
# Grammar: Incorrect Grammar
#
# Sentence 85: lmya උdaeesnin m awdi wii paslt yyi
# Grammar: Incorrect Grammar
#
# Sentence 86: ඔhu niwaerdi w akuru liyyi
# Grammar: Incorrect Grammar
#
# Sentence 87: ඇy niwaerdi w akuru liyyi
# Grammar: Incorrect Grammar
#
# Sentence 88: ඇy niwaerdi w akuru liynniiy
# Grammar: Incorrect Grammar
#
# Sentence 89: ඔhu lssn giithayk gayna kryi
# Grammar: Incorrect Grammar
#
# Sentence 90: ඇy lssn giithayk gayna kryi
# Grammar: Incorrect Grammar
#
# Sentence 91: ඇy lssn giithayk gayna krnniiy
# Grammar: Incorrect Grammar
#
# Sentence 92: nriya kaely maedin gmn kryi
# Grammar: Incorrect Grammar
#
# Sentence 93: sinhya kaely maedin gmn kryi
# Grammar: Incorrect Grammar
#
# Sentence 94: kotiya kaely maedin gmn kryi
# Grammar: Incorrect Grammar
#
# Sentence 95: ayiya උdaeesnin m awdi wii raekiyawt yyi
# Grammar: Incorrect Grammar
#
# Sentence 96: mama උdaeesnin m awdi wii raekiyawt yyi
# Grammar: Incorrect Grammar
#
# Sentence 97: k‍riidkya k‍riida pitiyt paemiණeyi
# Grammar: Incorrect Grammar
#
# Sentence 98: yeheliy sellm kiriimt pitiyt paemiණeyi
# Grammar: Incorrect Grammar
#
# Sentence 99: siiya midulee aඹ paelyk situwyi
# Grammar: Incorrect Grammar
#
# Sentence 100: aacci pooyt sil gaeniimt pnslt yyi
# Grammar: Incorrect Grammar
#
# Sentence 101: gs ithaa weegyen selweyi
# Grammar: Incorrect Grammar
#
# Sentence 102: srungly ahsee pawii pawii thaibeyi
# Grammar: Incorrect Grammar
#
# Sentence 103: naew syuree yatha‍ra krmin sitiyi
# Grammar: Incorrect Grammar
#
# Sentence 104: thaarkaw diipthaimthaw ahsee baebleyi
# Grammar: Incorrect Grammar
#
# Sentence 105: gs sulඟt idirii waeteyi
# Grammar: Incorrect Grammar
#
# Sentence 106: gngaw muhudt siiruwen gla bsiyi
# Grammar: Incorrect Grammar
#
# Sentence 107: ml prwii bim waeteyi
# Grammar: Incorrect Grammar
#
# Sentence 108: niws jl gaelmt hsu wii yt weyi
# Grammar: Incorrect Grammar
#
# Sentence 109: උdaeesnm lssn mlk pipeyi
# Grammar: Incorrect Grammar
#
# Sentence 110: ihl ahsee srunglyk paweyi
# Grammar: Incorrect Grammar
#
# Sentence 111: booly knden phlt perleyi
# Grammar: Incorrect Grammar
#
# Sentence 112: koly weegyen sulඟt gsagen yyi
# Grammar: Incorrect Grammar
#
# Sentence 113: ratha‍rii ahsee lssn tharuwk payyi
# Grammar: Incorrect Grammar
#
# Sentence 114: guwnwiduli yntha‍ry k‍riyathamk weyi
# Grammar: Incorrect Grammar
#
# Sentence 115: ruupwahinii yntha‍ry k‍riyathamk wemin thaibeyi
# Grammar: Incorrect Grammar
#
# Sentence 116: thaathathala midulee sitithai
# Grammar: Correct Grammar
#
# Sentence 117: thaathathala elwlu pathathaiwlt pohor dmthai
# Grammar: Correct Grammar
#
# Sentence 118: ammla kussiyee sitithai
# Grammar: Correct Grammar
#
# Sentence 119: ammla rs kaeemk sadthai
# Grammar: Correct Grammar
#
# Sentence 120: mllila midulee sellm krthai
# Grammar: Correct Grammar
#
# Sentence 121: nngila midulee sellm krthai
# Grammar: Correct Grammar
#
# Sentence 122: sinhyoo gs yt nidthai
# Grammar: Correct Grammar
#
# Sentence 123: weid‍ywru roogiyat behetha dethai
# Grammar: Correct Grammar
#
# Sentence 124: weid‍ywriyoo roogiyat behetha dethai
# Grammar: Correct Grammar
#
# Sentence 125: weid‍ywru roogiint kruණawen swn dethai
# Grammar: Correct Grammar
#
# Sentence 126: weid‍ywriyoo roogiint kruණawen kthaa  krthai
# Grammar: Correct Grammar
#
# Sentence 127: smnlyoo ml paeණi bothai
# Grammar: Correct Grammar
#
# Sentence 128: kurulloo gs උd paen paen ntthai
# Grammar: Correct Grammar
#
# Sentence 129: gayikawoo mihiri giithayk gythai
# Grammar: Correct Grammar
#
# Sentence 130: guruwru padm kiya dethai
# Grammar: Correct Grammar
#
# Sentence 131: akkla ශbd nga padm krthai
# Grammar: Correct Grammar
#
# Sentence 132: gowiyoo උdaeesnin kuඹurt ythai
# Grammar: Correct Grammar
#
# Sentence 133: kurulloo ahsee piyaඹthai
# Grammar: Correct Grammar
#
# Sentence 134: ඔwuhu gst naeg peer kdthai
# Grammar: Correct Grammar
#
# Sentence 135: ඔwuhu mh par aslt wii sitithai
# Grammar: Correct Grammar
#
# Sentence 136: ඔwuhu pyin m ngryt ythai
# Grammar: Correct Grammar
#
# Sentence 137: thaathathala kaelyt gos gs kpthai
# Grammar: Correct Grammar
#
# Sentence 138: mamla උdlu gen wl kotthai
# Grammar: Correct Grammar
#
# Sentence 139: gwyoo lpti thaණkol kthai
# Grammar: Correct Grammar
#
# Sentence 140: blloo ahst උdu burthai
# Grammar: Correct Grammar
#
# Sentence 141: hawoo weegyen paen paen ythai
# Grammar: Correct Grammar
#
# Sentence 142: thaarawoo waew jlyee weegyen piinthai
# Grammar: Correct Grammar
#
# Sentence 143: gowiyoo kethat baes goym kpthai
# Grammar: Correct Grammar
#
# Sentence 144: ඔwuhu raekiyawn bla pittha wethai
# Grammar: Correct Grammar
#
# Sentence 145: blloo weegyen paree duwthai
# Grammar: Correct Grammar
#
# Sentence 146: ammla wehes wii diwa aahar pisithai
# Grammar: Correct Grammar
#
# Sentence 147: akkla thaalyt pad thabmin ntthai
# Grammar: Correct Grammar
#
# Sentence 148: naendla yhptha waed krthai
# Grammar: Correct Grammar
#
# Sentence 149: naendla redi soo dmin sitithai
# Grammar: Correct Grammar
#
# Sentence 150: gewiliyoo kethat baes goym kpthai
# Grammar: Correct Grammar
#
# Sentence 151: gewiliyoo kethat baes goym situwthai
# Grammar: Correct Grammar
#
# Sentence 152: ammla rswtha aahar pisithai
# Grammar: Correct Grammar
#
# Sentence 153: akkla thaalyt giitha kiythai
# Grammar: Correct Grammar
#
# Sentence 154: eldennu pittniyee thaණkol kthai
# Grammar: Correct Grammar
#
# Sentence 155: eldennu pittniyee thaණkol kmin sitithai
# Grammar: Correct Grammar
#
# Sentence 156: ammla rswtha aahar sksmin sitithai
# Grammar: Correct Grammar
#
# Sentence 157: thaathathala dinpthaa raekiyawt ythai
# Grammar: Correct Grammar
#
# Sentence 158: akkla lssn gwum msmin sitithai
# Grammar: Correct Grammar
#
# Sentence 159: kurulloo aඹ gs muduණee sitithai
# Grammar: Correct Grammar
#
# Sentence 160: puusoo midul pura duwmin sellm krthai
# Grammar: Correct Grammar
#
# Sentence 161: mllila midul pura duwmin sellm krthai
# Grammar: Correct Grammar
#
# Sentence 162: nngila midul pura duwmin sellm krthai
# Grammar: Correct Grammar
#
# Sentence 163: blloo midul pura duwmin sellm krthai
# Grammar: Correct Grammar
#
# Sentence 164: guruwru gණithay padm niwaerdiw උgnwthai
# Grammar: Correct Grammar
#
# Sentence 165: guruwru paslt weelasnin paemiණethai
# Grammar: Correct Grammar
#
# Sentence 166: widuhlpthaiwru paslt weelasnin paemiණethai
# Grammar: Correct Grammar
#
# Sentence 167: kurulloo gs muduණee kuuduwk thanthai
# Grammar: Correct Grammar
#
# Sentence 168: gaykyoo mihiri giithayk gayna  krthai
# Grammar: Correct Grammar
#
# Sentence 169: guruwru lmyint padm kiya dethai
# Grammar: Correct Grammar
#
# Sentence 170: ayiyla ශbd nga padm krthai
# Grammar: Correct Grammar
#
# Sentence 171: gewiliyoo උdaeesnin kuඹurt ythai
# Grammar: Correct Grammar
#
# Sentence 172: උkussoo ahsee piyasrthai
# Grammar: Correct Grammar
#
# Sentence 173: ඔwuhu gst naeg aඹ kdthai
# Grammar: Correct Grammar
#
# Sentence 174: ඔwuhu pasl aslt wii sitithai
# Grammar: Correct Grammar
#
# Sentence 175: ඔwuhu pyin m pnsl bla ythai
# Grammar: Correct Grammar
#
# Sentence 176: ammla උdlu gen polow kotthai
# Grammar: Correct Grammar
#
# Sentence 177: ayiyla උdlu gen wl kotthai
# Grammar: Correct Grammar
#
# Sentence 178: gwyoo lpti thaණkol kthai
# Grammar: Correct Grammar
#
# Sentence 179: blloo weegyen duwmin sellm krthai
# Grammar: Correct Grammar
#
# Sentence 180: kaengruwoo weegyen paen paen ythai
# Grammar: Correct Grammar
#
# Sentence 181: mllila waew jlyee weegyen piinthai
# Grammar: Correct Grammar
#
# Sentence 182: gowiyoo kethat baes goym situwthai
# Grammar: Correct Grammar
#
# Sentence 183: ඔwuhu rajkarii bla pittha wethai
# Grammar: Correct Grammar
#
# Sentence 184: mllila weegyen wthauree piinthai
# Grammar: Correct Grammar
#
# Sentence 185: akkla diwa aahar pisithai
# Grammar: Correct Grammar
#
# Sentence 186: akkla giithaykt lssnt ntthai
# Grammar: Correct Grammar
#
# Sentence 187: naendla yhptha waed kiya dethai
# Grammar: Correct Grammar
#
# Sentence 188: naendla yhptha waedwlt yomu krthai
# Grammar: Correct Grammar
#
# Sentence 189: gowiyoo kethat baes wii isithai
# Grammar: Correct Grammar
#
# Sentence 190: gewiliyoo kethat baes goym pagthai
# Grammar: Correct Grammar
#
# Sentence 191: akkla giithaykt lssnt nrthanyee yedethai
# Grammar: Correct Grammar
#
# Sentence 192: akkla thaalyt athapudi gsthai
# Grammar: Correct Grammar
#
# Sentence 193: mgiyoo bsyt naeg sit gnithai
# Grammar: Correct Grammar
#
# Sentence 194: thaotiyoo ඔruw diytha krmin sitithai
# Grammar: Correct Grammar
#
# Sentence 195: palkyoo rt palny krthai
# Grammar: Correct Grammar
#
# Sentence 196: sthathau kaely maedin gmn krthai
# Grammar: Correct Grammar
#
# Sentence 197: ali waewen diy bothai
# Grammar: Correct Grammar
#
# Sentence 198: kuuඹi ශiitha kalyt kaeem raes krthai
# Grammar: Correct Grammar
#
# Sentence 199: akkla උdaeesnin m awdi wethai
# Grammar: Correct Grammar
#
# Sentence 200: lmyi උdaeesnin m awdi wii paslt ythai
# Grammar: Correct Grammar
#
# Sentence 201: ඔwuhu niwaerdi w akuru liythai
# Grammar: Correct Grammar
#
# Sentence 202: ඔwuhu niwaerdi thaalyt sindu kiythai
# Grammar: Correct Grammar
#
# Sentence 203: ඔwuhu thargyen jyg‍rhණy krthai
# Grammar: Correct Grammar
#
# Sentence 204: ඔwuhu lssn giithayk gayna  krthai
# Grammar: Correct Grammar
#
# Sentence 205: ඔwuhu lssn giithayk rඟ dkwthai
# Grammar: Correct Grammar
#
# Sentence 206: ඔwuhu paerණi kwiyk gayna  krthai
# Grammar: Correct Grammar
#
# Sentence 207: nri kaely maedin gmn krthai
# Grammar: Correct Grammar
#
# Sentence 208: sinhyoo kaely maedin gmn krthai
# Grammar: Correct Grammar
#
# Sentence 209: koti kaely maedin gmn krthai
# Grammar: Correct Grammar
#
# Sentence 210: ayiyla උdaeesnin m awdi wii raekiyawt ythai
# Grammar: Correct Grammar
#
# Sentence 211: mamla උdaeesnin m awdi wii raekiyawt ythai
# Grammar: Correct Grammar
#
# Sentence 212: k‍riidkyoo k‍riida pitiyt paemiණethai
# Grammar: Correct Grammar
#
# Sentence 213: yeheliyoo sellm kiriimt pitiyt paemiණethai
# Grammar: Correct Grammar
#
# Sentence 214: siiyla midulee aඹ pael situwthai
# Grammar: Correct Grammar
#
# Sentence 215: aaccila pooyt sil gaeniimt pnslt ythai
# Grammar: Correct Grammar
#
# Sentence 216: gs ithaa weegyen selweyi
# Grammar: Incorrect Grammar
#
# Sentence 217: srungl ahsee pawii pawii thaibeyi
# Grammar: Incorrect Grammar
#
# Sentence 218: naew syuree yatha‍ra kryi
# Grammar: Incorrect Grammar
#
# Sentence 219: thaarka diipthaimtha w ahsee baebleyi
# Grammar: Incorrect Grammar
#
# Sentence 220: gs sulඟt idirii waeteyi
# Grammar: Incorrect Grammar
#
# Sentence 221: gnga muhudt siiruwen gla bsiyi
# Grammar: Incorrect Grammar
#
# Sentence 222: ml prwii bim waeteyi
# Grammar: Incorrect Grammar
#
# Sentence 223: niwes jl gaelmt hsu wii yt weyi
# Grammar: Incorrect Grammar
#
# Sentence 224: උdaeesn m lssn ml pipeyi
# Grammar: Incorrect Grammar
#
# Sentence 225: ihl ahsee srungl paweyi
# Grammar: Incorrect Grammar
#
# Sentence 226: gl knden phlt perleyi
# Grammar: Incorrect Grammar
#
# Sentence 227: kol weegyen sulඟt gsagen yyi
# Grammar: Incorrect Grammar
#
# Sentence 228: ratha‍rii ahsee lssn tharu payyi
# Grammar: Incorrect Grammar
#
# Sentence 229: guwnwiduli yntha‍r k‍riyathamk weyi
# Grammar: Incorrect Grammar
#
# Sentence 230: ruupwahinii yntha‍r k‍riyathamk wemin thaibeyi
# Grammar: Incorrect Grammar
#
# Number of Correct Grammar Sentences: 100
# Number of Incorrect Grammar Sentences: 129
