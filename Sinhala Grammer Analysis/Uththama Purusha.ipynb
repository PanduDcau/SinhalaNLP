# %% [markdown]
# ### Uththama Purusha (First Person)

# %%
def sinhala_to_english(text):
    # Define a mapping dictionary for Sinhalese to English letters
    sinhala_to_english_mapping = {
        'ම': 'm', 'අ': 'a', 'ද': 'd', 'ග': 'g', 'ෙ': 'e',
        'හ': 'h', 'ප': 'p', 'බ': 'b',
        'ඉ': 'i', 'න': 'n', 'ට': 't', 'ත': 'tha',
        'ච': 'c', 'එ': 'e', 'ය': 'y', 'ල': 'l', 'ව': 'w',
        'ැ': 'ae', 'ළ': 'l', 'ආ': 'aa', 'ං': 'n',
        'ර': 'r', 'ජ': 'j', 'ස': 's', 'ෆ': 'f', 'භ': 'b',
        'ය': 'y', 'ි': 'i', 'ක': 'k',
        'ො': 'o', 'ඩ': 'd', '්': '', ' ': ' ', '.': '.',
        'ා': 'a', 'ැ': 'ae', 'ෑ': 'aee', 'ි': 'i', 'ී': 'ii',
        'ු': 'u', 'ූ': 'uu', 'ෘ': 'u', 'ෙ': 'e', 'ේ': 'ee',
        'ෛ': 'ei', 'ෝ': 'oo', 'ෞ': 'ou',
        'ෟ': 'o', 'ෲ': 'lu', 'ෳ': 'lu'
    }

    # Perform the conversion
    english_text = ""
    for char in text:
        if char in sinhala_to_english_mapping:
            english_text += sinhala_to_english_mapping[char]
        else:
            english_text += char

    return english_text

# %%
import re

def check_grammar(text, letter_combination):
    # Split the text into sentences
    sentences = text.split('.')

    results = []

    for sentence in sentences:
        # Split each sentence into words
        words = sentence.split()

        # Check if there are at least two words in the sentence
        if len(words) >= 1:
            last_word = words[-1].strip(".,!?")

            # Check if the last two letters of the last word match the specified letter combination
            if last_word[-2:].lower() == letter_combination.lower():
                results.append("Correct Grammar")
            else:
                results.append("Incorrect Grammar")
        else:
            # If there are no words in the sentence, it's considered incorrect grammar
            results.append("Incorrect Grammar")

    return results

# %%
import csv

# Provide a valid file path for your CSV file
# Specify the encoding that matches your CSV file

file_encoding = 'utf-8'  # You can change this to 'latin-1' or other encodings if needed
csv_file_path = "FirstPerson-PresentTense.csv"  # Replace with the path to your CSV file

all_rows = []  # List to store all rows as strings

with open(csv_file_path, 'r', newline='', encoding=file_encoding) as csvfile:
    csv_reader = csv.reader(csvfile)

    for row in csv_reader:
        if row:  # Check if the row is not empty
            # Combine the row's elements into a single string separated by dots
            row_string = '.'.join(row)
            all_rows.append(row_string)

# %%
joined_rows = '.'.join(all_rows)

# %%
all_rows
# Out:
# ['\ufeffමම නිතිපතා පන්සලට \u200dයමි',
#  'අපි නිතිපතා පන්සලට යමු',
#  'මම දිනපතා පාසල් යමි',
#  'අපි දිනපතා පාසල් යමු',
#  'මම මල් කැඩීමට යමි',
#  'අපි උදෙන් ම මල් කැඩීමට යමු',
#  'මම මල් පැළවලට වතුර දමමි',
#  'අපි මල් පැළවලට වතුර දමමු',
#  'මම කතන්දර පොතක් කියවමි',
#  'අපි කතන්දර පොත් කියවමු',
#  'මම දවසට දෙවරක් දත් මදිමි',
#  'අපි දවසට දෙවරක් දත් මදිමු',
#  'මම නිවැරදිව අකුරු ලියමි',
#  'අපි නිවැරදිව අකුරු ලියමු',
#  'මම ලස්සන කවියක් කියමි',
#  'අපි ලස්සන කවියක් කියමු',
#  'මම සරුංගලය උඩ යවමි',
#  'අපි සරුංගලය උඩ යවමු',
#  'මම සතුටින් ජීවත් වෙමි',
#  'අපි සතුටින් ජීවත් වෙමු',
#  'මම වැඩිහිටියන්ට ගරු කරමි',
#  'අපි වැඩිහිටියන්ට ගරු කරමු',
#  'මම වැඩිහිටියන්ගේ අවවාද පිළිපදිමි ',
#  'අපි  වැඩිහිටියන්ගේ අවවාද පිළිපදිමු',
#  'මම ගුරුවරුන්ගේ සිත් නො රිද්දමි',
#  'අපි ගුරුවරුන්ගේ සිත් නො රිද්දමු',
#  'මම රටට වැඩදායී පුද්ගලයෙක් වෙමි',
#  'අපි රටට වැඩදායී පුද්ගලයන් වෙමු',
#  'මම රටට සේවය කරමි',
#  'අපි රටට සේවය කරමු',
#  'මම ශාරීරික ව්\u200dයායාම්වල නිරත වෙමි',
#  'අපි ශාරීරික ව්\u200dයායාම්වල නිරත වෙමු',
#  'මම මිදුලේ සෙල්ලම් කරමි',
#  'අපි මිදුලේ සෙල්ලම් කරමු',
#  'මම රස කෑමක් සාදමි',
#  'අපි රස කෑමක් සාදමු',
#  'මම වේගයෙන් කැළයට දුවමි',
#  'අපි වේගයෙන් කැළයට දුවමු',
#  'මම උදෑසනින් අවදි වෙමි',
#  'අපි උදෑසනින් අවදි වෙමු',
#  'මම කතන්දර පොතක් ගනිමි',
#  'අපි කතන්දර පොත් ගනිමු',
#  'මම කවියක් පාඩම් කරමි',
#  'අපි කවියක් පාඩම් කරමු',
#  'මම රූපවාහිනිය නරඹමි',
#  'අපි රූපවාහිනිය නරඹමු',
#  'මම නාට්\u200dයයක් බැලීමට යමි',
#  'අපි නාට්\u200dයයක් බැලීමට යමු',
#  'මම මල් පැළයක් සිටුවමි',
#  'අපි මල් පැළ සිටුවමු',
#  'මම අහසේ තරු ගණන් කරමි',
#  'අපි අහසේ තරු ගණන් කරමු',
#  'මම දිනපතා අකුරු ලියමි',
#  'අපි දිනපතා අකුරු ලියමු',
#  'මම විවේකීව කාලය ගත කරමි',
#  'අපි විවේකීව කාලය ගත කරමු',
#  'මම බුදුන් පිදීමට යමි',
#  'අපි බුදුන් පිදීමට යමු',
#  'මම ක්\u200dරීඩා කිරීමට පිට්ටනියට යමි',
#  'අපි ක්\u200dරීඩා කිරීමට පිට්ටනියට යමු',
#  'මම පාඩම් කිරීමට පුස්තකාලයට යමි',
#  'අපි පාඩම් කිරීමට පුස්තකාලයට යමු ',
#  'මම දහම් පාසලට යමි',
#  'අපි දහම් පාසලට යමු',
#  'මම ගොයම් කැපීමට කුඹුරට යමි',
#  'අපි ගොයම් කැපීමට කුඹුරට යමු',
#  'මම වගා කිරීමට හේනට යමි',
#  'අපි වගා කිරීමට හේනට යමු',
#  'මම දර කැඩීමට කැළයට යමි',
#  'අපි දර කැඩීමට කැළයට යමු',
#  'මම වෙසක් කූඩුවක් සාදමි',
#  'අපි වෙසක් කූඩුවක් සාදමු',
#  'මම කුරුල්ලන්ට කෑම දමමි',
#  'අපි කුරුල්ලන්ට කෑම දමමු',
#  'මම සතුන්ට ආදරය කරමි',
#  'අපි සතුන්ට ආදරය කරමු',
#  'මම සතුන්ට කරුණාව දක්වමි',
#  'අපි සතුන්ට කරුණාව දක්වමු',
#  'මම පරිවර්තන කතා පොත් කියවමි',
#  'අපි පරිවර්තන කතා පොත් කියවමු',
#  'මම ගොයම් කැපීමේ අවස්ථාවකට සහභාගි වෙමි',
#  'අපි ගොයම් කැපීමේ අවස්ථාවකට සහභාගි වෙමු',
#  'මම ඉගෙන ගත් දේ ගැන මෙනෙහි කරමි',
#  'අපි ඉගෙන ගත් දේ ගැන මෙනෙහි කරමු',
#  'මම සමිතියේ දී කවියක් කියමි',
#  'අපි සමිතියේ දී කවියක් කියමු',
#  'මම සාහිත්\u200dය පොත් කියවමි',
#  'අපි සාහිත්\u200dය පොත් කියවමු',
#  'මම විවාද කණ්ඩායමට නායකත්වය දෙමි',
#  'අපි විවාද කණ්ඩායමට නායකත්වය දෙමු',
#  'මම දෙමව්පියන්ට කීකරු ලෙස හැදී වැඩෙමි',
#  'අපි දෙමව්පියන්ට කීකරු ලෙස හැදී වැඩෙමු',
#  'මම සමිතියේ දී නාට්\u200dයයක් ඉදිරිපත් කරමි',
#  'අපි සමිතියේ දී නාට්\u200dයයක් ඉදිරිපත් කරමු',
#  'මම මගේ පාසලට ආදරය කරමි',
#  'අපි අපේ පාසලට ආදරය කරමු',
#  'මම විභාගයට සාර්ථකව මුහුණ දෙමි',
#  'අපි විභාගයට සාර්ථකව මුහුණ දෙමු',
#  'මම ලස්සන රතු පැහැති ගවුමක් මසමි',
#  'අපි ලස්සන රතු පැහැති ගවුමක් මසමු']

# %%
joined_rows
# Out:
# '\ufeffමම නිතිපතා පන්සලට \u200dයමි.අපි නිතිපතා පන්සලට යමු.මම දිනපතා පාසල් යමි.අපි දිනපතා පාසල් යමු.මම මල් කැඩීමට යමි.අපි උදෙන් ම මල් කැඩීමට යමු.මම මල් පැළවලට වතුර දමමි.අපි මල් පැළවලට වතුර දමමු.මම කතන්දර පොතක් කියවමි.අපි කතන්දර පොත් කියවමු.මම දවසට දෙවරක් දත් මදිමි.අපි දවසට දෙවරක් දත් මදිමු.මම නිවැරදිව අකුරු ලියමි.අපි නිවැරදිව අකුරු ලියමු.මම ලස්සන කවියක් කියමි.අපි ලස්සන කවියක් කියමු.මම සරුංගලය උඩ යවමි.අපි සරුංගලය උඩ යවමු.මම සතුටින් ජීවත් වෙමි.අපි සතුටින් ජීවත් වෙමු.මම වැඩිහිටියන්ට ගරු කරමි.අපි වැඩිහිටියන්ට ගරු කරමු.මම වැඩිහිටියන්ගේ අවවාද පිළිපදිමි .අපි  වැඩිහිටියන්ගේ අවවාද පිළිපදිමු.මම ගුරුවරුන්ගේ සිත් නො රිද්දමි.අපි ගුරුවරුන්ගේ සිත් නො රිද්දමු.මම රටට වැඩදායී පුද්ගලයෙක් වෙමි.අපි රටට වැඩදායී පුද්ගලයන් වෙමු.මම රටට සේවය කරමි.අපි රටට සේවය කරමු.මම ශාරීරික ව්\u200dයායාම්වල නිරත වෙමි.අපි ශාරීරික ව්\u200dයායාම්වල නිරත වෙමු.මම මිදුලේ සෙල්ලම් කරමි.අපි මිදුලේ සෙල්ලම් කරමු.මම රස කෑමක් සාදමි.අපි රස කෑමක් සාදමු.ම
start_text = sinhala_to_english(letter_comb)
print("\nConverted Starting Letter:")
print(start_text)


def count_correct_grammar_sentences(english_text, start_text):
    # Check grammar using the previous code
    results = check_grammar(english_text, start_text)

    correct_grammar_count = results.count("Correct Grammar")
    incorrect_grammar_count = results.count("Incorrect Grammar")

    return correct_grammar_count, incorrect_grammar_count


# Check grammar using the previous code
results = check_grammar(english_text, start_text)
print("\nGrammar Check Results:")
sentences = english_text.split('.')
for i, sentence in enumerate(sentences):
    print(f"Sentence {i + 1}: {sentence.strip()}")
    print(f"Grammar: {results[i]}\n")

# Example usage:
correct_grammar_count, incorrect_grammar_count = count_correct_grammar_sentences(english_text, start_text)

print(f"Number of Correct Grammar Sentences: {correct_grammar_count}")
print(f"Number of Incorrect Grammar Sentences: {incorrect_grammar_count - 1}")
# Out:
# Input Text in Sinhala:
# ﻿මම නිතිපතා පන්සලට ‍යමි.අපි නිතිපතා පන්සලට යමු.මම දිනපතා පාසල් යමි.අපි දිනපතා පාසල් යමු.මම මල් කැඩීමට යමි.අපි උදෙන් ම මල් කැඩීමට යමු.මම මල් පැළවලට වතුර දමමි.අපි මල් පැළවලට වතුර දමමු.මම කතන්දර පොතක් කියවමි.අපි කතන්දර පොත් කියවමු.මම දවසට දෙවරක් දත් මදිමි.අපි දවසට දෙවරක් දත් මදිමු.මම නිවැරදිව අකුරු ලියමි.අපි නිවැරදිව අකුරු ලියමු.මම ලස්සන කවියක් කියමි.අපි ලස්සන කවියක් කියමු.මම සරුංගලය උඩ යවමි.අපි සරුංගලය උඩ යවමු.මම සතුටින් ජීවත් වෙමි.අපි සතුටින් ජීවත් වෙමු.මම වැඩිහිටියන්ට ගරු කරමි.අපි වැඩිහිටියන්ට ගරු කරමු.මම වැඩිහිටියන්ගේ අවවාද පිළිපදිමි .අපි  වැඩිහිටියන්ගේ අවවාද පිළිපදිමු.මම ගුරුවරුන්ගේ සිත් නො රිද්දමි.අපි ගුරුවරුන්ගේ සිත් නො රිද්දමු.මම රටට වැඩදායී පුද්ගලයෙක් වෙමි.අපි රටට වැඩදායී පුද්ගලයන් වෙමු.මම රටට සේවය කරමි.අපි රටට සේවය කරමු.මම ශාරීරික ව්‍යායාම්වල නිරත වෙමි.අපි ශාරීරික ව්‍යායාම්වල නිරත වෙමු.මම මිදුලේ සෙල්ලම් කරමි.අපි මිදුලේ සෙල්ලම් කරමු.මම රස කෑමක් සාදමි.අපි රස කෑමක් සාදමු.මම වේගයෙන් කැළයට දුවමි.අපි වේගයෙන් කැළයට දුවමු.මම උදෑසනින් අවදි වෙමි.අපි උදෑසනින් අවදි වෙමු.මම කතන්දර පොතක් ගනිමි.අපි කතන්දර පොත් ගනිමු.මම කවියක් පාඩම් කරමි.අපි කවියක් පාඩම් කරමු.මම රූපවාහිනිය නරඹමි.අපි රූපවාහිනිය නරඹමු.මම නාට්‍යයක් බැලීමට යමි.අපි නාට්‍යයක් බැලීමට යමු.මම මල් පැළයක් සිටුවමි.අපි මල් පැළ සිටුවමු.මම අහසේ තරු ගණන් කරමි.අපි අහසේ තරු ගණන් කරමු.මම දිනපතා අකුරු ලියම
‍yayamwl nirtha wemi.api ශariirik w‍yayamwl nirtha wemu.mm midulee sellm krmi.api midulee sellm krmu.mm rs kaeemk sadmi.api rs kaeemk sadmu.mm weegyen kaelyt duwmi.api weegyen kaelyt duwmu.mm උdaeesnin awdi wemi.api උdaeesnin awdi wemu.mm kthandr pothak gnimi.api kthandr potha gnimu.mm kwiyk padm krmi.api kwiyk padm krmu.mm ruupwahiniy nrඹmi.api ruupwahiniy nrඹmu.mm nat‍yyk baeliimt ymi.api nat‍yyk baeliimt ymu.mm ml paelyk situwmi.api ml pael situwmu.mm ahsee tharu gණn krmi.api ahsee tharu gණn krmu.mm dinpthaa akuru liymi.api dinpthaa akuru liymu.mm wiweekiiw kaly gtha krmi.api wiweekiiw kaly gtha krmu.mm budun pidiimt ymi.api budun pidiimt ymu.mm k‍riida kiriimt pittniyt ymi.api k‍riida kiriimt pittniyt ymu.mm padm kiriimt pusthakalyt ymi.api padm kiriimt pusthakalyt ymu .mm dhm paslt ymi.api dhm paslt ymu.mm goym kaepiimt kuඹurt ymi.api goym kaepiimt kuඹurt ymu.mm wga kiriimt heent ymi.api wga kiriimt heent ymu.mm dr kaediimt kaelyt ymi.api dr kaediimt kaelyt ymu.mm wesk kuuduwk sadmi.api wesk kuuduwk sadmu.mm kurullnt kaeem dmmi.api kurullnt kaeem dmmu.mm sthaunt aadry krmi.api sthaunt aadry krmu.mm sthaunt kruණaw dkwmi.api sthaunt kruණaw dkwmu.mm priwrthan kthaa potha kiywmi.api priwrthan kthaa potha kiywmu.mm goym kaepiimee awsථawkt shbagi wemi.api goym kaepiimee awsථawkt shbagi wemu.mm igen gtha dee gaen menehi krmi.api igen gtha dee gaen menehi krmu.mm smithaiyee dii kwiyk kiymi.api smithaiyee dii kwiyk kiymu.mm sahitha‍y potha kiywmi.api sahitha‍y potha kiywmu.mm wiwad kණdaymt naykthawy demi.api wiwad kණdaymt naykthawy demu.mm demwpiynt kiikru les haedii waedemi.api demwpiynt kiikru les haedii waedemu.mm smithaiyee dii nat‍yyk idiriptha krmi.api smithaiyee dii nat‍yyk idiriptha krmu.mm mgee paslt aadry krmi.api apee paslt aadry krmu.mm wibagyt sarථkw muhuණ demi.api wibagyt sarථkw muhuණ demu.mm lssn rthau paehaethai gwumk msmi.api lssn rthau paehaethai gwumk msmu
#
# Converted Starting Letter:
# mi
#
# Grammar Check Results:
# Sentence 1: ﻿mm nithaipthaa pnslt ‍ymi
# Grammar: Correct Grammar
#
# Sentence 2: api nithaipthaa pnslt ymu
# Grammar: Incorrect Grammar
#
# Sentence 3: mm dinpthaa pasl ymi
# Grammar: Correct Grammar
#
# Sentence 4: api dinpthaa pasl ymu
# Grammar: Incorrect Grammar
#
# Sentence 5: mm ml kaediimt ymi
# Grammar: Correct Grammar
#
# Sentence 6: api උden m ml kaediimt ymu
# Grammar: Incorrect Grammar
#
# Sentence 7: mm ml paelwlt wthaur dmmi
# Grammar: Correct Grammar
#
# Sentence 8: api ml paelwlt wthaur dmmu
# Grammar: Incorrect Grammar
#
# Sentence 9: mm kthandr pothak kiywmi
# Grammar: Correct Grammar
#
# Sentence 10: api kthandr potha kiywmu
# Grammar: Incorrect Grammar
#
# Sentence 11: mm dwst dewrk dtha mdimi
# Grammar: Correct Grammar
#
# Sentence 12: api dwst dewrk dtha mdimu
# Grammar: Incorrect Grammar
#
# Sentence 13: mm niwaerdiw akuru liymi
# Grammar: Correct Grammar
#
# Sentence 14: api niwaerdiw akuru liymu
# Grammar: Incorrect Grammar
#
# Sentence 15: mm lssn kwiyk kiymi
# Grammar: Correct Grammar
#
# Sentence 16: api lssn kwiyk kiymu
# Grammar: Incorrect Grammar
#
# Sentence 17: mm srungly උd ywmi
# Grammar: Correct Grammar
#
# Sentence 18: api srungly උd ywmu
# Grammar: Incorrect Grammar
#
# Sentence 19: mm sthautin jiiwtha wemi
# Grammar: Correct Grammar
#
# Sentence 20: api sthautin jiiwtha wemu
# Grammar: Incorrect Grammar
#
# Sentence 21: mm waedihitiynt gru krmi
# Grammar: Correct Grammar
#
# Sentence 22: api waedihitiynt gru krmu
# Grammar: Incorrect Grammar
#
# Sentence 23: mm waedihitiyngee awwad pilipdimi
# Grammar: Correct Grammar
#
# Sentence 24: api  waedihitiyngee awwad pilipdimu
# Grammar: Incorrect Grammar
#
# Sentence 25: mm guruwrungee sitha no riddmi
# Grammar: Correct Grammar
#
# Sentence 26: api guruwrungee sitha no riddmu
# Grammar: Incorrect Grammar
#
# Sentence 27: mm rtt waeddayii pudglyek wemi
# Grammar: Correct Grammar
#
# Sentence 28: api rtt waeddayii pudglyn wemu
# Grammar: Incorrect Grammar
#
# Sentence 29: mm rtt seewy krmi
# Grammar: Correct Grammar
#
# Sentence 30: api rtt seewy krmu
# Grammar: Incorrect Grammar
#
# Sentence 31: mm ශariirik w‍yayamwl nirtha wemi
# Grammar: Correct Grammar
#
# Sentence 32: api ශariirik w‍yayamwl nirtha wemu
# Grammar: Incorrect Grammar
#
# Sentence 33: mm midulee sellm krmi
# Grammar: Correct Grammar
#
# Sentence 34: api midulee sellm krmu
# Grammar: Incorrect Grammar
#
# Sentence 35: mm rs kaeemk sadmi
# Grammar: Correct Grammar
#
# Sentence 36: api rs kaeemk sadmu
# Grammar: Incorrect Grammar
#
# Sentence 37: mm weegyen kaelyt duwmi
# Grammar: Correct Grammar
#
# Sentence 38: api weegyen kaelyt duwmu
# Grammar: Incorrect Grammar
#
# Sentence 39: mm උdaeesnin awdi wemi
# Grammar: Correct Grammar
#
# Sentence 40: api උdaeesnin awdi wemu
# Grammar: Incorrect Grammar
#
# Sentence 41: mm kthandr pothak gnimi
# Grammar: Correct Grammar
#
# Sentence 42: api kthandr potha gnimu
# Grammar: Incorrect Grammar
#
# Sentence 43: mm kwiyk padm krmi
# Grammar: Correct Grammar
#
# Sentence 44: api kwiyk padm krmu
# Grammar: Incorrect Grammar
#
# Sentence 45: mm ruupwahiniy nrඹmi
# Grammar: Correct Grammar
#
# Sentence 46: api ruupwahiniy nrඹmu
# Grammar: Incorrect Grammar
#
# Sentence 47: mm nat‍yyk baeliimt ymi
# Grammar: Correct Grammar
#
# Sentence 48: api nat‍yyk baeliimt ymu
# Grammar: Incorrect Grammar
#
# Sentence 49: mm ml paelyk situwmi
# Grammar: Correct Grammar
#
# Sentence 50: api ml pael situwmu
# Grammar: Incorrect Grammar
#
# Sentence 51: mm ahsee tharu gණn krmi
# Grammar: Correct Grammar
#
# Sentence 52: api ahsee tharu gණn krmu
# Grammar: Incorrect Grammar
#
# Sentence 53: mm dinpthaa akuru liymi
# Grammar: Correct Grammar
#
# Sentence 54: api dinpthaa akuru liymu
# Grammar: Incorrect Grammar
#
# Sentence 55: mm wiweekiiw kaly gtha krmi
# Grammar: Correct Grammar
#
# Sentence 56: api wiweekiiw kaly gtha krmu
# Grammar: Incorrect Grammar
#
# Sentence 57: mm budun pidiimt ymi
# Grammar: Correct Grammar
#
# Sentence 58: api budun pidiimt ymu
# Grammar: Incorrect Grammar
#
# Sentence 59: mm k‍riida kiriimt pittniyt ymi
# Grammar: Correct Grammar
#
# Sentence 60: api k‍riida kiriimt pittniyt ymu
# Grammar: Incorrect Grammar
#
# Sentence 61: mm padm kiriimt pusthakalyt ymi
# Grammar: Correct Grammar
#
# Sentence 62: api padm kiriimt pusthakalyt ymu
# Grammar: Incorrect Grammar
#
# Sentence 63: mm dhm paslt ymi
# Grammar: Correct Grammar
#
# Sentence 64: api dhm paslt ymu
# Grammar: Incorrect Grammar
#
# Sentence 65: mm goym kaepiimt kuඹurt ymi
# Grammar: Correct Grammar
#
# Sentence 66: api goym kaepiimt kuඹurt ymu
# Grammar: Incorrect Grammar
#
# Sentence 67: mm wga kiriimt heent ymi
# Grammar: Correct Grammar
#
# Sentence 68: api wga kiriimt heent ymu
# Grammar: Incorrect Grammar
#
# Sentence 69: mm dr kaediimt kaelyt ymi
# Grammar: Correct Grammar
#
# Sentence 70: api dr kaediimt kaelyt ymu
# Grammar: Incorrect Grammar
#
# Sentence 71: mm wesk kuuduwk sadmi
# Grammar: Correct Grammar
#
# Sentence 72: api wesk kuuduwk sadmu
# Grammar: Incorrect Grammar
#
# Sentence 73: mm kurullnt kaeem dmmi
# Grammar: Correct Grammar
#
# Sentence 74: api kurullnt kaeem dmmu
# Grammar: Incorrect Grammar
#
# Sentence 75: mm sthaunt aadry krmi
# Grammar: Correct Grammar
#
# Sentence 76: api sthaunt aadry krmu
# Grammar: Incorrect Grammar
#
# Sentence 77: mm sthaunt kruණaw dkwmi
# Grammar: Correct Grammar
#
# Sentence 78: api sthaunt kruණaw dkwmu
# Grammar: Incorrect Grammar
#
# Sentence 79: mm priwrthan kthaa potha kiywmi
# Grammar: Correct Grammar
#
# Sentence 80: api priwrthan kthaa potha kiywmu
# Grammar: Incorrect Grammar
#
# Sentence 81: mm goym kaepiimee awsථawkt shbagi wemi
# Grammar: Correct Grammar
#
# Sentence 82: api goym kaepiimee awsථawkt shbagi wemu
# Grammar: Incorrect Grammar
#
# Sentence 83: mm igen gtha dee gaen menehi krmi
# Grammar: Correct Grammar
#
# Sentence 84: api igen gtha dee gaen menehi krmu
# Grammar: Incorrect Grammar
#
# Sentence 85: mm smithaiyee dii kwiyk kiymi
# Grammar: Correct Grammar
#
# Sentence 86: api smithaiyee dii kwiyk kiymu
# Grammar: Incorrect Grammar
#
# Sentence 87: mm sahitha‍y potha kiywmi
# Grammar: Correct Grammar
#
# Sentence 88: api sahitha‍y potha kiywmu
# Grammar: Incorrect Grammar
#
# Sentence 89: mm wiwad kණdaymt naykthawy demi
# Grammar: Correct Grammar
#
# Sentence 90: api wiwad kණdaymt naykthawy demu
# Grammar: Incorrect Grammar
#
# Sentence 91: mm demwpiynt kiikru les haedii waedemi
# Grammar: Correct Grammar
#
# Sentence 92: api demwpiynt kiikru les haedii waedemu
# Grammar: Incorrect Grammar
#
# Sentence 93: mm smithaiyee dii nat‍yyk idiriptha krmi
# Grammar: Correct Grammar
#
# Sentence 94: api smithaiyee dii nat‍yyk idiriptha krmu
# Grammar: Incorrect Grammar
#
# Sentence 95: mm mgee paslt aadry krmi
# Grammar: Correct Grammar
#
# Sentence 96: api apee paslt aadry krmu
# Grammar: Incorrect Grammar
#
# Sentence 97: mm wibagyt sarථkw muhuණ demi
# Grammar: Correct Grammar
#
# Sentence 98: api wibagyt sarථkw muhuණ demu
# Grammar: Incorrect Grammar
#
# Sentence 99: mm lssn rthau paehaethai gwumk msmi
# Grammar: Correct Grammar
#
# Sentence 100: api lssn rthau paehaethai gwumk msmu
# Grammar: Incorrect Grammar
#
# Number of Correct Grammar Sentences: 50
# Number of Incorrect Grammar Sentences: 49

# %% [markdown]
# ## For "Api" Sentence

# %%
input_text = joined_rows
letter_comb = "මු"

# %%
# Convert Sinhala letters to English
english_text = sinhala_to_english(input_text)
print("Input Text in Sinhala:")
print(input_text)
print("\nConverted to English Letters:")
print(english_text)

start_text = sinhala_to_english(letter_comb)
print("\nConverted Starting Letter:")
print(start_text)


def count_correct_grammar_sentences(english_text, start_text):
    # Check grammar using the previous code
    results = check_grammar(english_text, start_text)

    correct_grammar_count = results.count("Correct Grammar")
    incorrect_grammar_count = results.count("Incorrect Grammar")

    return correct_grammar_count, incorrect_grammar_count


# Check grammar using the previous code
results = check_grammar(english_text, start_text)
print("\nGrammar Check Results:")
sentences = english_text.split('.')
for i, sentence in enumerate(sentences):
    print(f"Sentence {i + 1}: {sentence.strip()}")
    print(f"Grammar: {results[i]}\n")

# Example usage:
correct_grammar_count, incorrect_grammar_count = count_correct_grammar_sentences(english_text, start_text)

print(f"Number of Correct Grammar Sentences: {correct_grammar_count}")
print(f"Number of Incorrect Grammar Sentences: {incorrect_grammar_count - 1}")
# Out:
# Input Text in Sinhala:
# ﻿මම නිතිපතා පන්සලට ‍යමි.අපි නිතිපතා පන්සලට යමු.මම දිනපතා පාසල් යමි.අපි දිනපතා පාසල් යමු.මම මල් කැඩීමට යමි.අපි උදෙන් ම මල් කැඩීමට යමු.මම මල් පැළවලට වතුර දමමි.අපි මල් පැළවලට වතුර දමමු.මම කතන්දර පොතක් කියවමි.අපි කතන්දර පොත් කියවමු.මම දවසට දෙවරක් දත් මදිමි.අපි දවසට දෙවරක් දත් මදිමු.මම නිවැරදිව අකුරු ලියමි.අපි නිවැරදිව අකුරු ලියමු.මම ලස්සන කවියක් කියමි.අපි ලස්සන කවියක් කියමු.මම
t aadry krmi.api sthaunt aadry krmu.mm sthaunt kruණaw dkwmi.api sthaunt kruණaw dkwmu.mm priwrthan kthaa potha kiywmi.api priwrthan kthaa potha kiywmu.mm goym kaepiimee awsථawkt shbagi wemi.api goym kaepiimee awsථawkt shbagi wemu.mm igen gtha dee gaen menehi krmi.api igen gtha dee gaen menehi krmu.mm smithaiyee dii kwiyk kiymi.api smithaiyee dii kwiyk kiymu.mm sahitha‍y potha kiywmi.api sahitha‍y potha kiywmu.mm wiwad kණdaymt naykthawy demi.api wiwad kණdaymt naykthawy demu.mm demwpiynt kiikru les haedii waedemi.api demwpiynt kiikru les haedii waedemu.mm smithaiyee dii nat‍yyk idiriptha krmi.api smithaiyee dii nat‍yyk idiriptha krmu.mm mgee paslt aadry krmi.api apee paslt aadry krmu.mm wibagyt sarථkw muhuණ demi.api wibagyt sarථkw muhuණ demu.mm lssn rthau paehaethai gwumk msmi.api lssn rthau paehaethai gwumk msmu
#
# Converted Starting Letter:
# mu
#
# Grammar Check Results:
# Sentence 1: ﻿mm nithaipthaa pnslt ‍ymi
# Grammar: Incorrect Grammar
#
# Sentence 2: api nithaipthaa pnslt ymu
# Grammar: Correct Grammar
#
# Sentence 3: mm dinpthaa pasl ymi
# Grammar: Incorrect Grammar
#
# Sentence 4: api dinpthaa pasl ymu
# Grammar: Correct Grammar
#
# Sentence 5: mm ml kaediimt ymi
# Grammar: Incorrect Grammar
#
# Sentence 6: api උden m ml kaediimt ymu
# Grammar: Correct Grammar
#
# Sentence 7: mm ml paelwlt wthaur dmmi
# Grammar: Incorrect Grammar
#
# Sentence 8: api ml paelwlt wthaur dmmu
# Grammar: Correct Grammar
#
# Sentence 9: mm kthandr pothak kiywmi
# Grammar: Incorrect Grammar
#
# Sentence 10: api kthandr potha kiywmu
# Grammar: Correct Grammar
#
# Sentence 11: mm dwst dewrk dtha mdimi
# Grammar: Incorrect Grammar
#
# Sentence 12: api dwst dewrk dtha mdimu
# Grammar: Correct Grammar
#
# Sentence 13: mm niwaerdiw akuru liymi
# Grammar: Incorrect Grammar
#
# Sentence 14: api niwaerdiw akuru liymu
# Grammar: Correct Grammar
#
# Sentence 15: mm lssn kwiyk kiymi
# Grammar: Incorrect Grammar
#
# Sentence 16: api lssn kwiyk kiymu
# Grammar: Correct Grammar
#
# Sentence 17: mm srungly උd ywmi
# Grammar: Incorrect Grammar
#
# Sentence 18: api srungly උd ywmu
# Grammar: Correct Grammar
#
# Sentence 19: mm sthautin jiiwtha wemi
# Grammar: Incorrect Grammar
#
# Sentence 20: api sthautin jiiwtha wemu
# Grammar: Correct Grammar
#
# Sentence 21: mm waedihitiynt gru krmi
# Grammar: Incorrect Grammar
#
# Sentence 22: api waedihitiynt gru krmu
# Grammar: Correct Grammar
#
# Sentence 23: mm waedihitiyngee awwad pilipdimi
# Grammar: Incorrect Grammar
#
# Sentence 24: api  waedihitiyngee awwad pilipdimu
# Grammar: Correct Grammar
#
# Sentence 25: mm guruwrungee sitha no riddmi
# Grammar: Incorrect Grammar
#
# Sentence 26: api guruwrungee sitha no riddmu
# Grammar: Correct Grammar
#
# Sentence 27: mm rtt waeddayii pudglyek wemi
# Grammar: Incorrect Grammar
#
# Sentence 28: api rtt waeddayii pudglyn wemu
# Grammar: Correct Grammar
#
# Sentence 29: mm rtt seewy krmi
# Grammar: Incorrect Grammar
#
# Sentence 30: api rtt seewy krmu
# Grammar: Correct Grammar
#
# Sentence 31: mm ශariirik w‍yayamwl nirtha wemi
# Grammar: Incorrect Grammar
#
# Sentence 32: api ශariirik w‍yayamwl nirtha wemu
# Grammar: Correct Grammar
#
# Sentence 33: mm midulee sellm krmi
# Grammar: Incorrect Grammar
#
# Sentence 34: api midulee sellm krmu
# Grammar: Correct Grammar
#
# Sentence 35: mm rs kaeemk sadmi
# Grammar: Incorrect Grammar
#
# Sentence 36: api rs kaeemk sadmu
# Grammar: Correct Grammar
#
# Sentence 37: mm weegyen kaelyt duwmi
# Grammar: Incorrect Grammar
#
# Sentence 38: api weegyen kaelyt duwmu
# Grammar: Correct Grammar
#
# Sentence 39: mm උdaeesnin awdi wemi
# Grammar: Incorrect Grammar
#
# Sentence 40: api උdaeesnin awdi wemu
# Grammar: Correct Grammar
#
# Sentence 41: mm kthandr pothak gnimi
# Grammar: Incorrect Grammar
#
# Sentence 42: api kthandr potha gnimu
# Grammar: Correct Grammar
#
# Sentence 43: mm kwiyk padm krmi
# Grammar: Incorrect Grammar
#
# Sentence 44: api kwiyk padm krmu
# Grammar: Correct Grammar
#
# Sentence 45: mm ruupwahiniy nrඹmi
# Grammar: Incorrect Grammar
#
# Sentence 46: api ruupwahiniy nrඹmu
# Grammar: Correct Grammar
#
# Sentence 47: mm nat‍yyk baeliimt ymi
# Grammar: Incorrect Grammar
#
# Sentence 48: api nat‍yyk baeliimt ymu
# Grammar: Correct Grammar
#
# Sentence 49: mm ml paelyk situwmi
# Grammar: Incorrect Grammar
#
# Sentence 50: api ml pael situwmu
# Grammar: Correct Grammar
#
# Sentence 51: mm ahsee tharu gණn krmi
# Grammar: Incorrect Grammar
#
# Sentence 52: api ahsee tharu gණn krmu
# Grammar: Correct Grammar
#
# Sentence 53: mm dinpthaa akuru liymi
# Grammar: Incorrect Grammar
#
# Sentence 54: api dinpthaa akuru liymu
# Grammar: Correct Grammar
#
# Sentence 55: mm wiweekiiw kaly gtha krmi
# Grammar: Incorrect Grammar
#
# Sentence 56: api wiweekiiw kaly gtha krmu
# Grammar: Correct Grammar
#
# Sentence 57: mm budun pidiimt ymi
# Grammar: Incorrect Grammar
#
# Sentence 58: api budun pidiimt ymu
# Grammar: Correct Grammar
#
# Sentence 59: mm k‍riida kiriimt pittniyt ymi
# Grammar: Incorrect Grammar
#
# Sentence 60: api k‍riida kiriimt pittniyt ymu
# Grammar: Correct Grammar
#
# Sentence 61: mm padm kiriimt pusthakalyt ymi
# Grammar: Incorrect Grammar
#
# Sentence 62: api padm kiriimt pusthakalyt ymu
# Grammar: Correct Grammar
#
# Sentence 63: mm dhm paslt ymi
# Grammar: Incorrect Grammar
#
# Sentence 64: api dhm paslt ymu
# Grammar: Correct Grammar
#
# Sentence 65: mm goym kaepiimt kuඹurt ymi
# Grammar: Incorrect Grammar
#
# Sentence 66: api goym kaepiimt kuඹurt ymu
# Grammar: Correct Grammar
#
# Sentence 67: mm wga kiriimt heent ymi
# Grammar: Incorrect Grammar
#
# Sentence 68: api wga kiriimt heent ymu
# Grammar: Correct Grammar
#
# Sentence 69: mm dr kaediimt kaelyt ymi
# Grammar: Incorrect Grammar
#
# Sentence 70: api dr kaediimt kaelyt ymu
# Grammar: Correct Grammar
#
# Sentence 71: mm wesk kuuduwk sadmi
# Grammar: Incorrect Grammar
#
# Sentence 72: api wesk kuuduwk sadmu
# Grammar: Correct Grammar
#
# Sentence 73: mm kurullnt kaeem dmmi
# Grammar: Incorrect Grammar
#
# Sentence 74: api kurullnt kaeem dmmu
# Grammar: Correct Grammar
#
# Sentence 75: mm sthaunt aadry krmi
# Grammar: Incorrect Grammar
#
# Sentence 76: api sthaunt aadry krmu
# Grammar: Correct Grammar
#
# Sentence 77: mm sthaunt kruණaw dkwmi
# Grammar: Incorrect Grammar
#
# Sentence 78: api sthaunt kruණaw dkwmu
# Grammar: Correct Grammar
#
# Sentence 79: mm priwrthan kthaa potha kiywmi
# Grammar: Incorrect Grammar
#
# Sentence 80: api priwrthan kthaa potha kiywmu
# Grammar: Correct Grammar
#
# Sentence 81: mm goym kaepiimee awsථawkt shbagi wemi
# Grammar: Incorrect Grammar
#
# Sentence 82: api goym kaepiimee awsථawkt shbagi wemu
# Grammar: Correct Grammar
#
# Sentence 83: mm igen gtha dee gaen menehi krmi
# Grammar: Incorrect Grammar
#
# Sentence 84: api igen gtha dee gaen menehi krmu
# Grammar: Correct Grammar
#
# Sentence 85: mm smithaiyee dii kwiyk kiymi
# Grammar: Incorrect Grammar
#
# Sentence 86: api smithaiyee dii kwiyk kiymu
# Grammar: Correct Grammar
#
# Sentence 87: mm sahitha‍y potha kiywmi
# Grammar: Incorrect Grammar
#
# Sentence 88: api sahitha‍y potha kiywmu
# Grammar: Correct Grammar
#
# Sentence 89: mm wiwad kණdaymt naykthawy demi
# Grammar: Incorrect Grammar
#
# Sentence 90: api wiwad kණdaymt naykthawy demu
# Grammar: Correct Grammar
#
# Sentence 91: mm demwpiynt kiikru les haedii waedemi
# Grammar: Incorrect Grammar
#
# Sentence 92: api demwpiynt kiikru les haedii waedemu
# Grammar: Correct Grammar
#
# Sentence 93: mm smithaiyee dii nat‍yyk idiriptha krmi
# Grammar: Incorrect Grammar
#
# Sentence 94: api smithaiyee dii nat‍yyk idiriptha krmu
# Grammar: Correct Grammar
#
# Sentence 95: mm mgee paslt aadry krmi
# Grammar: Incorrect Grammar
#
# Sentence 96: api apee paslt aadry krmu
# Grammar: Correct Grammar
#
# Sentence 97: mm wibagyt sarථkw muhuණ demi
# Grammar: Incorrect Grammar
#
# Sentence 98: api wibagyt sarථkw muhuණ demu
# Grammar: Correct Grammar
#
# Sentence 99: mm lssn rthau paehaethai gwumk msmi
# Grammar: Incorrect Grammar
#
# Sentence 100: api lssn rthau paehaethai gwumk msmu
# Grammar: Correct Grammar
#
# Number of Correct Grammar Sentences: 50
# Number of Incorrect Grammar Sentences: 49
